# %% [markdown]
# # Sentiment analysis with Random forest
# <p> Part 2 / 4 create word vectors and vocabulary </p>

# %%
# Import the pandas package, then use the "read_csv" function to read the labeled training data
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
import json
import codecs
from sklearn.externals import joblib
from collections import Counter

# %% [markdown]
# ### Hyperparams

# %%
serialize_train_datafile = "/mnt/basket/processingData/volatile/telco_train_dataset.json"

serialize_word2vec_features = "/mnt/basket/processingData/volatile/telco_data_features.npy"
serialize_word2vec_vocabulary = "/mnt/basket/processingData/volatile/telco_data_vocab.json"
serialize_word2vec_vectorizer = "/mnt/basket/processingData/volatile/telco_data_vectorizer.joblib"

# %% [markdown]
# ### Load cleaned data

# %%
with codecs.open(serialize_train_datafile, 'r', encoding='utf-8') as f:
	clean_train_reviews = json.load(f)

# %%
# extract the second column which contains the reviews
list_of_reviews = [row[2] for row in clean_train_reviews]
print "Example review: [" , list_of_reviews[1] , "]"
print "Training dataset lenght: " , len(list_of_reviews)
# Out:
# Example review: [ anschlusswechsel dauert schon ueber drei monate immer vollzogen erste verzoegerung mehrfache falsche bearbeitung wechselauftrags zweite verzoegerung vertrag falsch aufgesetzt wurde check rabatte wurden beruecksichtigt wurde entertain s statt gebuchten m bestaetigt gleichen preis umstaendliche hotline langen wartezeiten wenigen hilfreichen groesstenteils inkompetenten mitarbeitern teilweise respektlos wahrscheinlich eigener hilflosigkeit luegen gegenueber kunden auftreten kunde wechselprozess staendiges nachfragen vorantreiben fehler telekom teilweise identifizieren korrektur anstossen telekom versprochenes feedback wirklich erhalten telekom fertig bevor vertrag begonnen mangels geeigneter alternativen fuer gewuenschten vertrag wechsel geblieben ]
# Training dataset lenght:  3455

# %% [markdown]
# ### Creating Features from a Bag of Words (Using scikit-learn)
# <p> Initialize the "CountVectorizer" object, which is scikit-learn's bag of words tool. </p>

# %%
print "Creating the bag of words...\n"

vectorizer = CountVectorizer(analyzer = "word",   \
                             tokenizer = None,    \
                             preprocessor = None, \
                             stop_words = None,   \
                             max_features = 5000)

# fit_transform() does two functions: 
#   - First, it fits the model and learns the vocabulary; 
#   - Second, it transforms our training data into feature vectors. 
# The input to fit_transform should be a list of strings.
train_data_features = vectorizer.fit_transform(list_of_reviews)
# Out:
# Creating the bag of words...

# %%
# Numpy arrays are easy to work with, so convert the result to an array
train_data_features = train_data_features.toarray()
print Counter(train_data_features[0])
print Counter(train_data_features[10])
print train_data_features.shape
# Out:
# Counter({0: 4978, 1: 22})
# Counter({0: 4996, 1: 4})
# (3455, 5000)

# %% [markdown]
# ### Vocabulary

# %%
# Take a look at the words in the vocabulary
vocab = vectorizer.get_feature_names()
print vocab
# Out:
# [u'ab', u'abaendern', u'abarbeitung', u'abbestellung', u'abbrueche', u'abbruechen', u'abbschalten', u'abbuchen', u'abbuchung', u'abdesetzt', u'abend', u'abends', u'abendstunden', u'abfolge', u'abgeben', u'abgebrochenen', u'abgebucht', u'abgefragt', u'abgehandelt', u'abgeht', u'abgelaufen', u'abgelegenen', u'abgelegt', u'abgelehnt', u'abgemacht', u'abgemeldet', u'abgerechnet', u'abgerufen', u'abgesagt', u'abgeschaltet', u'abgeschickt', u'abgeschlossen', u'abgeschlossene', u'abgeschlossenen', u'abgesehen', u'abgesetzt', u'abgesprochen', u'abgestimmt', u'abgewickelt', u'abgewimmelt', u'abgezogen', u'abhaengig', u'abhaengigkeit', u'abhanden', u'abhilfe', u'abholen', u'abietern', u'ablaeufe', u'ablaeuft', u'ablauf', u'ablaufes', u'ablehnung', u'abmachungen', u'abmeldung', u'abo', u'abraten', u'abrechnung', u'abrechnungen', u'abruf', u'abrufen', u'absagen', u'absagt', u'abschalttag', u'abschalttermin', u'abschaltung', u'abschliessen', u'abschluss', u'abschlusstermin', u'absetzen', u'absichlich', u'absolut', u'absolute', u'absoluten', u'absoluter', u'abspecken', u'abspeisung', u'absprache', u'absprachen', u'absprechen', u'abstand', u'abstimmung', u'abstinenz', u'abstuerzen', u'absturz', u'abteilung', u'abteilungen', u'abteilungsleiter', u'abwaten', u'abwechslung', u'abweichender', u'abwickelung', u'abwicklung', u'abwikling', u'abwiklung', u'abwohl', u'abzuarbeiten', u'abzug', u'abzuholen', u'abzurufen', u'abzuschliessen', u'abzuwarten', u'abzuwickeln', u'abzuwimmeln', u'account', u'ach', u'achnung', u'acht', u'achtung', u'adapter', u'address', u'aderpaare', u'administrativer', u'adressaenderung', u'adressdaten', u'adresse', u'adresswechsels', u'ae', u'aehnlich', u'aehnliches', u'aelter', u'aendern', u'aenderung', u'aenderungen', u'aerger', u'aergerlich', u'aergernissen', u'aeusserst', u'aeusserungen', u'agb', u'agiert', u'ahnung', u'ahnungslosigkeit', u'aktion', u'aktionen', u'aktionsvorteile', u'aktiv', u'aktivieren', u'aktiviert', u'aktivierte', u'aktivierung', u'aktivierungscode', u'aktuell', u'aktuelle', u'aktuellen', u'aktueller', u'akzeptabel', u'akzeptabler', u'akzeptanz', u'akzeptiert', u'ales', u'aless', u'alice', u'all', u'allein', u'alleine', u'alleingelassen', u'allerdings', u'allerletzte', u'allerunterste', u'allgemein', u'allgemeine', u'allles', u'alls', u'allten', u'alptraumhaft', u'alt', u'altanbieter', u'altanbieters', u'altanschluss', u'altbaus', u'alte', u'alten', u'alter', u'alternative', u'alternativen', u'alternativtermine', u'although', u'amazon', u'analog', u'analogen', u'anbieten', u'anbieter', u'anbietern', u'anbieters', u'anbieterwecheln', u'anbieterwechsel', u'anbieterwechseln', u'anbietet', u'anbindung', u'and', u'andauerde', u'andauernd', u'andauernden', u'andererseits', u'andernfalls', u'anderswo', u'andren', u'androhen', u'androhung', u'andwort', u'anerkannt', u'anfaellig', u'anfaenglich', u'anfaenglichem', u'anfahrt', u'anfahrtskosten', u'anfallen', u'anfang', u'anfangs', u'anfangsschwierigkeiten', u'anforderung', u'anfrage', u'anfragen', u'angaben', u'angabge', u'angeblich', u'angebliche', u'angebot', u'angebote', u'angeboten', u'angebotene', u'angebotspreis', u'angebracht', u'angefallenen', u'angefertigt', u'angefragt', u'angegangen', u'angegeben', u'angegebene', u'angegebenen', u'angehalten', u'angehen', u'angeht', u'angekommen', u'angekuendigt', u'angekuendigte', u'angekuendigten', u'angelegt', u'angelogen', u'angemeldet', u'angemessen', u'angemessenen', u'angenehm', u'angenehme', u'angenehmen', u'angenehmer', u'angenommen', u'angepasst', u'angerufen', u'angerufenen', u'angeschalten', u'angeschaltet', u'angeschlossen', u'angeschrieben', u'angewiesen', u'angezeigt', u'angst', u'angts', u'anhaltende', u'anhieb', u'ankamen', u'ankommen', u'ankommt', u'ankopplung', u'ankuendigung', u'ankuendigungen', u'anlaeufe', u'anlage', u'anlauf', u'anlaufschwierigkeiten', u'anlaufschwirigkeiten', u'anleitung', u'anleitungen', u'anlieferung', u'anliegen', u'anmedungsunterlagen', u'anmelde', u'anmelden', u'anmeldun ...

# %%
# Sum up the counts of each vocabulary word
dist = np.sum(train_data_features, axis=0)

# For each, print the vocabulary word and the number of times it appears in the training set
for tag, count in zip(vocab, dist):
    print count, tag
# Out:
# 26 ab
# 1 abaendern
# 2 abarbeitung
# 1 abbestellung
# 2 abbrueche
# 1 abbruechen
# 1 abbschalten
# 1 abbuchen
# 3 abbuchung
# 1 abdesetzt
# 3 abend
# 4 abends
# 1 abendstunden
# 1 abfolge
# 3 abgeben
# 1 abgebrochenen
# 13 abgebucht
# 1 abgefragt
# 1 abgehandelt
# 1 abgeht
# 10 abgelaufen
# 1 abgelegenen
# 1 abgelegt
# 2 abgelehnt
# 1 abgemacht
# 1 abgemeldet
# 3 abgerechnet
# 1 abgerufen
# 2 abgesagt
# 3 abgeschaltet
# 1 abgeschickt
# 5 abgeschlossen
# 2 abgeschlossene
# 1 abgeschlossenen
# 1 abgesehen
# 1 abgesetzt
# 3 abgesprochen
# 1 abgestimmt
# 2 abgewickelt
# 1 abgewimmelt
# 1 abgezogen
# 1 abhaengig
# 1 abhaengigkeit
# 1 abhanden
# 1 abhilfe
# 1 abholen
# 1 abietern
# 2 ablaeufe
# 3 ablaeuft
# 18 ablauf
# 1 ablaufes
# 1 ablehnung
# 1 abmachungen
# 1 abmeldung
# 1 abo
# 1 abraten
# 6 abrechnung
# 1 abrechnungen
# 1 abruf
# 1 abrufen
# 1 absagen
# 1 absagt
# 1 abschalttag
# 1 abschalttermin
# 1 abschaltung
# 2 abschliessen
# 3 abschluss
# 1 abschlusstermin
# 1 absetzen
# 1 absichlich
# 19 absolut
# 6 absolute
# 1 absoluten
# 1 absoluter
# 1 abspecken
# 1 abspeisung
# 9 absprache
# 5 absprachen
# 1 absprechen
# 2 abstand
# 1 abstimmung
# 1 abstinenz
# 1 abstuerzen
# 1 absturz
# 4 abteilung
# 2 abteilungen
# 1 abteilungsleiter
# 1 abwaten
# 1 abwechslung
# 1 abweichender
# 1 abwickelung
# 89 abwicklung
# 1 abwikling
# 2 abwiklung
# 1 abwohl
# 1 abzuarbeiten
# 1 abzug
# 1 abzuholen
# 2 abzurufen
# 1 abzuschliessen
# 1 abzuwarten
# 2 abzuwickeln
# 1 abzuwimmeln
# 2 account
# 2 ach
# 1 achnung
# 1 acht
# 1 achtung
# 1 adapter
# 1 address
# 1 aderpaare
# 1 administrativer
# 1 adressaenderung
# 1 adressdaten
# 14 adresse
# 1 adresswechsels
# 1 ae
# 1 aehnlich
# 2 aehnliches
# 1 aelter
# 4 aendern
# 1 aenderung
# 2 aenderungen
# 13 aerger
# 8 aergerlich
# 1 aergernissen
# 2 aeusserst
# 1 aeusserungen
# 2 agb
# 1 agiert
# 3 ahnung
# 1 ahnungslosigkeit
# 2 aktion
# 1 aktionen
# 1 aktionsvorteile
# 5 aktiv
# 2 aktivieren
# 6 aktiviert
# 1 aktivierte
# 6 aktivierung
# 2 aktivierungscode
# 9 aktuell
# 2 aktuelle
# 8 aktuellen
# 1 aktueller
# 2 akzeptabel
# 1 akzeptabler
# 1 akzeptanz
# 4 akzeptiert
# 3 ales
# 1 aless
# 4 alice
# 3 all
# 1 allein
# 5 alleine
# 1 alleingelassen
# 40 allerdings
# 2 allerletzte
# 1 allerunterste
# 1 allgemein
# 1 allgemeine
# 1 allles
# 1 alls
# 1 allten
# 1 alptraumhaft
# 3 alt
# 5 altanbieter
# 1 altanbieters
# 1 altanschluss
# 1 altbaus
# 12 alte
# 37 alten
# 7 alter
# 2 alternative
# 2 alternativen
# 1 alternativtermine
# 1 although
# 1 amazon
# 1 analog
# 2 analogen
# 6 anbieten
# 93 anbieter
# 7 anbietern
# 6 anbieters
# 1 anbieterwecheln
# 6 anbieterwechsel
# 1 anbieterwechseln
# 2 anbietet
# 2 anbindung
# 7 and
# 1 andauerde
# 2 andauernd
# 1 andauernden
# 1 andererseits
# 1 andernfalls
# 1 anderswo
# 1 andren
# 1 androhen
# 1 androhung
# 1 andwort
# 1 anerkannt
# 1 anfaellig
# 3 anfaenglich
# 1 anfaenglichem
# 3 anfahrt
# 1 anfahrtskosten
# 1 anfallen
# 21 anfang
# 3 anfangs
# 1 anfangsschwierigkeiten
# 1 anforderung
# 10 anfrage
# 15 anfragen
# 7 angaben
# 1 angabge
# 12 angeblich
# 1 angebliche
# 25 angebot
# 1 angebote
# 16 angeboten
# 1 angebotene
# 1 angebotspreis
# 1 angebracht
# 2 angefallenen
# 1 angefertigt
# 1 angefragt
# 1 angegangen
# 10 angegeben
# 1 angegebene
# 9 angegebenen
# 1 angehalten
# 1 angehen
# 1 angeht
# 3 angekommen
# 14 angekuendigt
# 1 angekuendigte
# 1 angekuendigten
# 1 angelegt
# 1 angelogen
# 2 angemeldet
# 1 angemessen
# 1 angemessenen
# 1 angenehm
# 2 angenehme
# 1 angenehmen
# 2 angenehmer
# 1 angenommen
# 1 angepasst
# 22 angerufen
# 1 angerufenen
# 1 angeschalten
# 1 angeschaltet
# 10 angeschlossen
# 1 angeschrieben
# 1 angewiesen
# 3 angezeigt
# 1 angst
# 1 angts
# 1 anhaltende
# 8 anhieb
# 2 ankamen
# 2 ankommen
# 2 ankommt
# 1 ankopplung
# 6 ankuendigung
# 1 ankuendigungen
# 3 anlaeufe
# 3 anlage
# 3 anlauf
# 1 anlaufschwierigkeiten
# 1 anlaufschwirigkeiten
# 6 anleitung
# 2 anleitungen
# 1 anlieferung
# 5 anliegen
# 1 anmedungsunterlagen
# 1 anmelde
# 1 anmelden
# 7 anmeldung
# 1 anmeldungen
# 2 annaehernd
# 1 annahme
# 1 annehmen
# 1 anonymer
# 1 another
# 1 anraten
# 3 anrief
# 1 anrtrag
# 31 anruf
# 1 anrufbeantworter
# 12 anrufe
# 24 anrufen
# 1 anruflisten
# 5 anruft
# 4 ans
# 3 ansage
# 1 ansatz
# 1 ansatzweise
# 1 anschalten
# 1 anschalttag
# 11 anschalttermin
# 6 anschaltung
# 1 anschaltungstermin
# 2 anscheinend
# 1 anschkusstermin
# 1 anschliessen
# 2 anschliessend
# 1 anschliessendem
# 1 anschliessender
# 1 anschlu
# 1 anschluess
# 1 anschluesse
# 326 anschluss
# 1 anschlussadresse
# 1 anschlussart
# 2 anschlussdaten
# 1 anschlussdatum
# 1 anschlussdauer
# 1 anschlussdetails
# 1 anschlussdose
# 36 anschlusses
# 1 anschlussfreigabe
# 3 anschlussfreischaltung
# 1 anschlussgebuehr
# 1 anschlussgebuehren
# 1 anschlusslegung
# 1 anschlussprobleme
# 3 anschlusstag
# 1 anschlussteemin
# 38 anschlusstermin
# 1 anschlusstermine
# 2 anschlussterminen
# 1 anschlussterminierung
# 1 anschlusstermins
# 1 anschlusswechsel
# 2 anschlusszeit
# 2 anschlusszeiten
# 1 anschlusszermines
# 1 anschluuss
# 3 anschreiben
# 2 anschrift
# 13 ansonsten
# 1 ansprechbar
# 29 ansprechpartner
# 1 ansprechpartnern
# 4 anspruch
# 1 anstand
# 2 anstandslos
# 1 anstat
# 6 anstatt
# 1 anstehen
# 1 anstossen
# 1 antenne
# 1 antennenkabel
# 13 antrag
# 3 antrages
# 1 antrags
# 1 antragsbearbeitung
# 19 antwort
# 10 antworten
# 1 anungslos
# 1 anwenderfreundlich
# 1 anwesend
# 1 anwesenheit
# 1 any
# 1 anything
# 2 anzahl
# 1 anzeige
# 1 anzeigt
# 1 anzubieten
# 1 anzuhoeren
# 1 anzurufen
# 2 anzuschliessen
# 2 anzutreffen
# 1 aol
# 1 app
# 1 apparat
# 1 apps
# 4 april
# 1 apwikln
# 2 arbeit
# 8 arbeiten
# 2 arbeiter
# 1 arbeitet
# 1 arbeitgeber
# 1 arbeitsabfolgen
# 1 arbeitsaufwendig
# 1 arbeitstag
# 1 arbeitstage
# 1 arcor
# 1 are
# 1 arm
# 1 aror
# 1 arrogant
# 4 art
# 1 artikel
# 1 as
# 1 at
# 1 atem
# 1 auchn
# 1 aufbau
# 1 aufbaut
# 1 auffenommen
# 3 aufforderung
# 1 aufgeblaeht
# 3 aufgefallen
# 1 aufgefordert
# 2 aufgefuehrt
# 1 aufgegeben
# 1 aufgehoben
# 2 aufgelegt
# 1 aufgeloest
# 2 aufgeschaltet
# 1 aufgeschlagen
# 1 aufgeschlossen
# 1 aufgeschluesselte
# 1 aufgeschwatzt
# 1 aufgesetzt
# 1 aufgetaucht
# 2 aufgetreten
# 1 aufgetretenen
# 1 aufgetretenes
# 11 aufgrund
# 1 aufhaenger
# 1 aufjeden
# 1 aufklaerung
# 1 aufladen
# 1 aufmerksam
# 1 aufrecht
# 2 aufs
# 2 aufschalt
# 7 aufschaltung
# 1 aufschlag
# 1 aufschlussreiche
# 1 aufschub
# 1 aufsetze
# 1 aufsetzen
# 1 aufstellbar
# 1 auftagserteilung
# 3 auftraege
# 52 auftrag
# 1 auftragabwicklung
# 1 auftrage
# 13 auftrages
# 10 auftrags
# 4 auftragsabwicklung
# 1 auftragsannahme
# 2 auftragsausfuehrung
# 7 auftragsbearbeitung
# 16 auftragsbestaetigung
# 1 auftragsdatum
# 1 auftragseingang
# 2 auftragserledigung
# 1 auftragserstellung
# 2 auftragserteilung
# 1 auftragsleistungstag
# 2 auftragsnummer
# 4 auftragsstatus
# 1 auftragsstornierung
# 1 auftragsuebernahme
# 1 auftragsverlauf
# 1 auftrat
# 2 auftraten
# 3 auftreten
# 1 auftretende
# 2 auftretenden
# 1 auftritt
# 1 aufwaendig
# 2 aufwand
# 1 aufzunehmen
# 1 auge
# 4 augen
# 4 august
# 1 ausbauen
# 1 ausdruecklich
# 1 auseinandersetzen
# 1 auser
# 6 ausfaelle
# 1 ausfaellt
# 8 ausfall
# 2 ausfuehrlich
# 6 ausfuehrliche
# 10 ausfuehrung
# 1 ausfuellen
# 2 ausgebaut
# 1 ausgebautes
# 1 ausgebildet
# 1 ausgebotet
# 7 ausgefuehrt
# 1 ausgefuellten
# 1 ausgefuhlt
# 1 ausgelacht
# 1 ausgelaufen
# 1 ausgemachte
# 1 ausgerueckt
# 1 ausgesprochen
# 1 ausgestellt
# 1 ausgestellte
# 1 ausgetausch
# 2 ausgetauscht
# 1 ausgetauschten
# 1 ausgezahlt
# 1 ausgezeichnet
# 1 ausgiebig
# 1 ausgleich
# 1 ausharren
# 3 auskommen
# 8 auskuenfte
# 20 auskunft
# 2 ausland
# 1 ausliest
# 2 ausnahme
# 1 ausrede
# 1 ausreden
# 5 ausreichend
# 9 aussage
# 1 aussagefaehigkeit
# 1 aussagekraeftig
# 10 aussagen
# 1 ausschalten
# 1 ausschlaggebender
# 1 ausschliesslich
# 1 ausschlusskriterium
# 1 aussendienst
# 1 aussendienstmitarbeiter
# 1 aussendiensttechniker
# 1 aussenwand
# 7 ausser
# 9 ausserdem
# 1 aussergewoehnliches
# 1 ausserordentlich
# 2 ausserordentlichen
# 2 aussetzer
# 3 aussicht
# 1 aussieht
# 1 aussortieren
# 1 aussser
# 1 ausstattung
# 2 aussuchen
# 3 austausch
# 1 auswahl
# 1 ausweichmoeglichkeit
# 1 auszahlung
# 1 auszufuellen
# 1 auszuschalten
# 1 auszutauschen
# 1 auto
# 5 automatisch
# 2 automatische
# 1 automatischen
# 1 automatisierung
# 1 autorisiert
# 1 autragserteilung
# 1 auzubauen
# 2 avisierten
# 1 bald
# 1 ballungsgebiet
# 2 bandansagen
# 17 bandbreite
# 1 bangen
# 1 banking
# 1 basic
# 2 basiert
# 1 bauseits
# 1 bbisher
# 1 be
# 1 beabeitung
# 1 beachtet
# 2 beanstanden
# 1 beanstandet
# 2 beanstandung
# 2 beanstandungen
# 1 beanstondungen
# 1 beantragen
# 6 beantragt
# 1 beantragte
# 1 beantragten
# 2 beantragung
# 3 beantworten
# 16 beantwortet
# 2 beantwortung
# 6 bearbeiten
# 11 bearbeitet
# 93 bearbeitung
# 1 bearbeitungs
# 3 bearbeitungsdauer
# 1 bearbeitungsfortschritt
# 1 bearbeitungsfristen
# 5 bearbeitungsstand
# 2 bearbeitungsstatus
# 10 bearbeitungszeit
# 3 bearbeitungszeiten
# 1 bearbeiung
# 1 beauftrag
# 1 beauftragen
# 6 beauftragt
# 1 beauftragung
# 1 because
# 1 becomes
# 1 bedarf
# 1 bedauert
# 1 bedenken
# 2 bedeutet
# 1 bedienen
# 1 bedient
# 2 bedienung
# 2 bedingt
# 1 beduerfnisse
# 1 bedurfte
# 1 beeinflusst
# 1 been
# 2 beenden
# 1 beendete
# 1 beendigung
# 1 before
# 1 befreien
# 1 befriedigendes
# 1 befugnisse
# 1 befugt
# 1 begin
# 2 beginn
# 4 beginnt
# 1 begleichung
# 1 begleitmaterial
# 2 begonnen
# 1 begrenzte
# 3 begruendung
# 1 begruessungsbrief
# 2 begruessungsschreiben
# 1 begutachten
# 2 behalten
# 2 behandelt
# 1 behaupted
# 2 behauptet
# 7 beheben
# 3 behebung
# 16 behoben
# 1 beibehalten
# 3 beiden
# 1 beides
# 1 beigelegten
# 1 beigetragen
# 1 beiliegenden
# 82 beim
# 2 beispiel
# 1 beitrag
# 1 beiu
# 1 bekaeme
# 16 bekam
# 5 bekannt
# 1 bekannte
# 3 bekannten
# 1 bekanntes
# 2 beklagen
# 1 bekomm
# 9 bekomme
# 68 bekommen
# 15 bekommt
# 1 belaestigen
# 1 belaestigung
# 2 belange
# 1 belangen
# 1 belastet
# 2 belegt
# 1 belehrt
# 1 beleidigt
# 1 beleidigung
# 1 beliefern
# 4 belogen
# 1 beluegt
# 1 bemaengele
# 2 bemaengeln
# 1 bemerkt
# 1 bemerkten
# 5 bemuehen
# 31 bemueht
# 1 bemuehte
# 1 bemuehten
# 1 bemuehter
# 1 bemuehungen
# 1 benachrichtigen
# 4 benachrichtigt
# 2 benachrichtigung
# 1 benachrichtigungen
# 1 benannten
# 1 benehmen
# 1 benjamin
# 1 benoetigen
# 3 benoetigt
# 2 benoetigte
# 1 benoetung
# 1 benutzbar
# 1 benutzen
# 1 benutzt
# 9 beraten
# 6 berater
# 1 beratng
# 78 beratung
# 1 beratungen
# 1 beratungs
# 1 beratungsangebot
# 2 berechnen
# 11 berechnet
# 3 berechnung
# 1 bereich
# 4 bereit
# 1 bereitet
# 1 bereitete
# 4 bereitgestellt
# 1 bereitgestellten
# 27 bereits
# 1 bereitschaft
# 1 bereitschaftsgebuehr
# 1 bereitsstellung
# 30 bereitstellung
# 1 bereitstellungsort
# 5 bereitstellungstermin
# 1 bereitstellungszeit
# 1 bereitstellungszeiten
# 2 bereitzustellen
# 3 bereut
# 6 berichten
# 1 berichtet
# 2 berlin
# 1 berliner
# 1 berrater
# 3 beruecksichtigt
# 1 beruflich
# 1 besagten
# 1 beschaedigt
# 1 beschaemend
# 1 beschaffen
# 4 bescheid
# 1 bescheiden
# 1 bescheuert
# 1 beschimpft
# 1 beschleunigung
# 1 beschraenkung
# 1 beschreiben
# 5 beschreibung
# 2 beschreibungen
# 5 beschrieben
# 1 beschwehrlich
# 7 beschwerde
# 2 beschwerdebrief
# 2 beschwerden
# 2 beschwerdestelle
# 1 beschweren
# 1 beseitigen
# 4 beseitigt
# 1 beseitigung
# 1 besitzer
# 1 besitzt
# 2 besondere
# 1 besonderer
# 21 besonders
# 1 besorgen
# 2 besprochen
# 15 besser
# 6 bessere
# 1 besseren
# 1 besserer
# 2 besseres
# 1 besserung
# 1 bestaedigt
# 1 bestaedigung
# 1 bestaendige
# 1 bestaetigen
# 12 bestaetigt
# 1 bestaetigten
# 19 bestaetigung
# 1 bestaetigungen
# 1 bestaetigungsmails
# 1 bestandskunde
# 1 bestandskunden
# 5 beste
# 2 bestehen
# 1 bestehende
# 5 bestehenden
# 4 besteht
# 1 bestell
# 1 bestellbestaetigung
# 2 bestellen
# 2 bestellphase
# 1 bestellstatus
# 18 bestellt
# 5 bestellte
# 5 bestellten
# 22 bestellung
# 1 bestellungsabwicklng
# 1 bestellungseingang
# 1 besten
# 17 bestens
# 1 bester
# 1 bestes
# 1 bestimmen
# 1 bestimmt
# 1 bestimmte
# 2 bestimmten
# 7 besuch
# 1 betens
# 1 betraege
# 1 betraegen
# 1 betraegt
# 1 betraf
# 2 betrag
# 2 betragen
# 1 betrags
# 1 betreffend
# 1 betreiberfirma
# 2 betreung
# 1 betreut
# 7 betreuung
# 1 betreuut
# 3 betrieb
# 1 betrifft
# 1 betruegerisch
# 1 betrug
# 1 between
# 1 beurteilen
# 1 beurteilung
# 4 bevor
# 1 bewerkstelligen
# 1 bewerkstelligt
# 1 bewertbar
# 2 bewerten
# 6 bewertung
# 1 bewertungen
# 1 bewohner
# 2 beworbenen
# 2 bewusst
# 2 bezahle
# 6 bezahlen
# 6 bezahlt
# 1 bezeichnungen
# 1 bezgl
# 1 beziehung
# 4 bezueglich
# 2 bezug
# 1 bgruessung
# 1 bieher
# 2 bieten
# 4 bietet
# 1 bilanz
# 1 bilden
# 2 bildqualitaet
# 1 billige
# 2 billiger
# 1 billing
# 1 binn
# 1 binnen
# 1 bischen
# 74 bisher
# 2 bisherige
# 11 bisherigen
# 1 bisheriger
# 1 bisjetzt
# 12 bislang
# 3 bisschen
# 1 biten
# 9 bitte
# 1 bittet
# 1 bjr
# 1 bleibe
# 6 bleiben
# 8 bleibt
# 1 blick
# 3 blieb
# 4 blieben
# 1 blinkt
# 1 blockiert
# 1 bloedsinn
# 1 bloss
# 1 bock
# 1 bohrt
# 1 bomardiert
# 1 boni
# 1 bonitaetspruefung
# 9 bonus
# 1 bonusauszahlung
# 4 bot
# 1 botschaften
# 1 bott
# 12 box
# 1 boxen
# 1 brachte
# 1 brachten
# 1 brauch
# 1 brauchen
# 3 braucht
# 3 brauchte
# 1 brechen
# 1 brei
# 1 bremer
# 4 bricht
# 1 bridge
# 11 brief
# 5 briefe
# 1 briefen
# 1 briefinfos
# 1 briefkasten
# 1 briefpost
# 1 briefwechsel
# 1 brigitte
# 5 bringen
# 2 bringt
# 1 brstens
# 2 bruchteil
# 2 buchen
# 1 buchstabenfehler
# 1 bucht
# 1 buchte
# 1 buechse
# 5 buehne
# 1 buero
# 1 buis
# 1 bundes
# 1 bundesnetzagentur
# 1 but
# 1 buy
# 1 bw
# 2 by
# 2 bzgl
# 31 bzw
# 30 ca
# 12 call
# 6 callcenter
# 1 callcentermitarbeiter
# 1 callya
# 1 can
# 1 cancell
# 1 card
# 9 cashback
# 1 caution
# 1 cd
# 1 cent
# 11 center
# 1 centers
# 1 chance
# 1 channels
# 8 chaos
# 1 chaosladen
# 1 chaotisch
# 1 chaotischen
# 1 chaotischer
# 1 charged
# 2 chat
# 47 check
# 1 chef
# 1 chefetage
# 1 chemnitz
# 1 chose
# 1 cih
# 3 circa
# 1 code
# 1 com
# 1 comfort
# 1 communication
# 3 company
# 3 computer
# 1 computerprogrammen
# 1 connect
# 2 contract
# 1 country
# 1 crc
# 1 ct
# 2 customer
# 6 dabei
# 1 dach
# 2 dachte
# 7 dadurch
# 1 daerte
# 19 dafuer
# 1 dagegen
# 1 daheim
# 17 daher
# 5 dahin
# 1 damals
# 7 dame
# 1 damen
# 1 dan
# 9 danach
# 3 dank
# 15 danke
# 1 dankeschoen
# 1 dannach
# 1 dar
# 5 daran
# 11 darauf
# 5 daraufhin
# 2 daraus
# 3 darf
# 1 daruber
# 14 darueber
# 4 darum
# 1 darunter
# 170 dass
# 1 dasteht
# 12 daten
# 1 datendurchsatzes
# 1 datenfluss
# 1 datenmenge
# 1 datenrate
# 1 datenuebermittlung
# 1 datenvolumen
# 5 dato
# 8 datum
# 8 dauer
# 2 dauerhaft
# 1 dauerhafte
# 5 dauern
# 1 dauernd
# 1 dauernden
# 15 dauert
# 11 dauerte
# 1 dauerten
# 5 daumen
# 7 davon
# 2 davor
# 1 dazubuchen
# 1 dazugebucht
# 1 dazukaufen
# 1 dazwischen
# 4 de
# 1 debatten
# 1 deckt
# 1 dect
# 5 defekt
# 1 defekte
# 2 defekten
# 2 definitiv
# 2 dei
# 1 deklaratio
# 1 deklariert
# 1 delivery
# 1 dementsprechend
# 12 denen
# 1 denke
# 1 dennen
# 5 dennoch
# 2 derart
# 4 deren
# 1 derluckenwalder
# 6 derzeit
# 1 derzeitigen
# 4 deshalb
# 1 desinteressiert
# 1 dessau
# 7 deswegen
# 2 desweiteren
# 1 detailierter
# 2 detaillierte
# 1 detaillierten
# 11 deutlich
# 1 deutliche
# 1 deutsch
# 1 deutschen
# 4 deutschland
# 1 deutschlandchef
# 1 dez
# 3 dezember
# 1 dfb
# 2 dhl
# 2 didn
# 4 dienst
# 1 dienste
# 2 dienstleister
# 1 dienstleistung
# 1 diesbezueglich
# 1 diesbezuegliche
# 5 dinge
# 14 direkt
# 4 direkte
# 1 direktem
# 1 direkten
# 1 diskussionen
# 1 disorganisierter
# 1 display
# 1 disposition
# 1 diverse
# 1 do
# 3 dokumentation
# 1 dokusystem
# 1 dolle
# 1 don
# 1 donnerstag
# 1 dont
# 1 doof
# 1 doppelrechnung
# 2 doppelt
# 2 doppelte
# 1 dorf
# 1 douple
# 9 download
# 1 downloadspeed
# 1 draengeln
# 1 draengt
# 1 draethchen
# 7 dran
# 2 drauf
# 17 drei
# 1 dreimal
# 1 dreist
# 4 drin
# 1 dringlich
# 2 dritte
# 1 drittel
# 1 dritten
# 1 drittes
# 1 droht
# 1 drohung
# 2 drosselung
# 1 drueber
# 3 drum
# 168 dsl
# 15 durchgefuehrt
# 2 durchgehend
# 2 durchkommt
# 2 durchsatz
# 2 durchzufuehren
# 9 easy
# 13 easybox
# 4 eben
# 8 ebenfalls
# 2 ebenso
# 6 echt
# 3 egal
# 2 eh
# 2 ehem
# 7 eher
# 3 ehrlich
# 3 eigene
# 4 eigenen
# 2 eigenes
# 2 eigeninitiative
# 11 eigentlich
# 4 eindeutig
# 2 eindruck
# 80 einfach
# 23 einfache
# 7 einfacher
# 2 einfachste
# 3 eingang
# 10 eingegangen
# 80 eingehalten
# 3 eingehaltenen
# 15 eingerichtet
# 7 eingestellt
# 2 eingetragen
# 3 eingezogen
# 11 einhaltung
# 3 einigermassen
# 11 einrichten
# 41 einrichtung
# 6 einsatz
# 2 einschalten
# 2 einschalttermin
# 2 einschaltung
# 2 einschreiben
# 4 einsehen
# 3 einstellen
# 2 einstellung
# 2 eintragung
# 2 eintreffen
# 32 einwandfrei
# 2 einwandfreie
# 2 einwandfreier
# 3 einzelnen
# 12 einzige
# 2 einziger
# 3 einziges
# 4 einzigste
# 1 einzugsermaechtigung
# 1 einzugstag
# 3 einzurichten
# 1 einzuschaetzen
# 1 einzusehen
# 1 einzustellen
# 1 eirichtungstermin
# 1 eiwandfrei
# 1 elder
# 2 elektriker
# 1 elektrohandel
# 1 elektronisch
# 1 elektronischen
# 1 elektrotechnischen
# 1 elend
# 17 email
# 6 emails
# 1 empfaenger
# 1 empfahl
# 6 empfang
# 2 empfangen
# 23 empfehlen
# 5 empfehlenswert
# 2 empfehlung
# 11 ende
# 2 endeffekt
# 3 endgeraeten
# 2 endgueltig
# 33 endlich
# 2 engagement
# 2 engagierte
# 2 engagierter
# 9 entertain
# 2 entgegenkommen
# 9 entschaedigung
# 4 entschieden
# 4 entschuldigt
# 2 entschuldigung
# 1 entsprechend
# 3 entsprechende
# 1 entstande
# 3 entstanden
# 1 entstandene
# 2 entstandenen
# 1 entstoert
# 1 entstoerungsdienst
# 2 enttaeuschend
# 7 enttaeuscht
# 1 entwickle
# 1 equipment
# 2 erachtens
# 1 erahrungen
# 1 erbarmte
# 1 erbautem
# 1 erbost
# 2 erbracht
# 1 erbrachte
# 1 erbringen
# 1 erfaehrt
# 7 erfahren
# 6 erfahrung
# 7 erfahrungen
# 4 erfasst
# 1 erfassung
# 1 erfoglte
# 1 erfogte
# 1 erfold
# 4 erfolg
# 4 erfolgen
# 4 erfolglos
# 6 erfolgreich
# 18 erfolgt
# 30 erfolgte
# 3 erfolgten
# 1 erforderichen
# 5 erforderlich
# 3 erforderliche
# 1 erforderlichen
# 1 erforderten
# 2 erfragen
# 2 erfragt
# 2 erfreulich
# 1 erfuellen
# 5 erfuellt
# 2 erfuhr
# 3 ergab
# 1 ergaenzen
# 1 ergeben
# 4 ergebnis
# 1 ergebnislose
# 1 ergebnisse
# 1 ergruenden
# 3 erhaelt
# 1 erhalt
# 6 erhalte
# 60 erhalten
# 2 erhaltene
# 1 erheblichen
# 1 erheblicher
# 10 erhielt
# 2 erhielten
# 1 erhlten
# 1 erinnert
# 6 erinnerung
# 3 erinnerungen
# 1 erinnerungsnachricht
# 1 erinnerungsservice
# 1 erkennbar
# 1 erkennbaren
# 1 erkennen
# 7 erklaeren
# 3 erklaert
# 1 erklaerten
# 4 erklaerung
# 1 erkundigt
# 1 erlaeuterungen
# 1 erlaub
# 1 erleben
# 4 erlebt
# 14 erledigt
# 6 erledigung
# 1 ermaesigung
# 1 ermahnen
# 1 erneuert
# 3 erneut
# 1 erneutem
# 1 erneuten
# 1 erneuter
# 2 ernst
# 1 eroeffnete
# 1 erreichar
# 61 erreichbar
# 1 erreichbare
# 1 erreichbaren
# 1 erreichbarer
# 61 erreichbarkeit
# 15 erreichen
# 12 erreicht
# 1 ersatzanschluss
# 2 ersatztermin
# 1 ersatztermine
# 2 erscheinen
# 2 erscheint
# 4 erschien
# 5 erschienen
# 1 erschlossen
# 1 ersetzt
# 1 ersichtlich
# 1 ersichtlichen
# 147 erst
# 1 erstanmeldung
# 1 erstanschluss
# 1 erstantrag
# 2 erstattet
# 3 erstattung
# 1 erstaunlich
# 1 erstaunt
# 23 erste
# 3 erstellen
# 4 erstellt
# 1 erstellte
# 1 erstellung
# 23 ersten
# 5 erster
# 1 erstklassig
# 1 erstkunden
# 5 erstmal
# 1 erstnutzung
# 2 erteilt
# 1 erwarte
# 1 erwarten
# 6 erwartet
# 1 erwartete
# 1 erweitern
# 1 erwirken
# 1 erwischen
# 2 erzaehlen
# 4 erzaehlt
# 1 erzeugt
# 1 etage
# 10 etc
# 4 etliche
# 1 etlichen
# 2 etwa
# 1 eune
# 5 eur
# 4 euro
# 1 europaflat
# 2 euros
# 2 even
# 2 eventuell
# 1 ever
# 1 evig
# 1 evtl
# 1 ewe
# 17 ewig
# 3 ewige
# 1 ewiges
# 2 ewigkeit
# 1 ewigkeiten
# 1 ex
# 1 exakt
# 4 exakte
# 1 expensive
# 2 explizit
# 1 externer
# 13 extra
# 1 extrakosten
# 11 extrem
# 2 extreme
# 1 fache
# 1 fachgerechte
# 1 fachkompetent
# 2 fachkompetenz
# 1 fachkundig
# 1 fachlich
# 1 fachmaennisch
# 1 fachmann
# 2 fachwissen
# 2 faden
# 2 faehig
# 1 faehigen
# 1 faehrt
# 1 faehrte
# 2 faelle
# 1 faellen
# 1 faellig
# 5 faellt
# 1 faelschlicherweise
# 1 faengt
# 1 fahrtkosten
# 3 faire
# 1 fairness
# 1 fakt
# 1 faktor
# 15 fall
# 2 falle
# 1 fallen
# 1 fallloesend
# 1 falls
# 20 falsch
# 1 falschaussagen
# 20 falsche
# 5 falschen
# 8 falscher
# 1 falscherfassung
# 2 falsches
# 1 familie
# 16 fand
# 1 fanden
# 1 fangen
# 1 fasch
# 29 fast
# 2 fax
# 1 faxversand
# 8 fazit
# 3 februar
# 3 feedback
# 1 fehl
# 1 fehlanfahrt
# 1 fehlbestellung
# 4 fehlende
# 1 fehlenden
# 27 fehler
# 3 fehlerbehebung
# 1 fehlerfrei
# 1 fehlerfreien
# 2 fehlerhafte
# 2 fehlerhaften
# 3 fehlerhafter
# 1 fehlermeldungen
# 3 fehlern
# 3 fehlers
# 1 fehlersuche
# 1 fehlgeschlagenen
# 2 fehlt
# 1 fehlte
# 1 feiertagen
# 1 fein
# 1 feischaltung
# 1 ferne
# 1 ferneingriff
# 1 ferner
# 1 fernmuendlich
# 3 fernsehen
# 1 fernseher
# 1 fertig
# 1 fertigen
# 1 fertiggestellt
# 1 fertigung
# 3 fest
# 1 festegstellt
# 1 festen
# 1 festes
# 1 festgestellt
# 1 festlegungen
# 16 festnetz
# 3 festnetzanschluss
# 1 festnetzflat
# 4 festnetznummer
# 1 festplattenrekorder
# 1 feststellen
# 1 few
# 1 fiel
# 1 fiktive
# 2 filiale
# 1 fillialen
# 2 filme
# 2 final
# 1 finally
# 1 finanz
# 1 finanzielle
# 1 find
# 12 finde
# 6 finden
# 1 finger
# 4 firma
# 1 firmen
# 1 firmenanschluss
# 1 firmenseite
# 2 fix
# 1 flachzange
# 1 flat
# 4 flexibel
# 1 flexible
# 1 flexiebel
# 1 fliessend
# 1 flog
# 1 flop
# 3 flott
# 2 flotte
# 1 flughafen
# 1 flur
# 1 fluss
# 1 flut
# 1 flyer
# 4 folge
# 1 folgende
# 2 folgenden
# 1 folgt
# 1 folgte
# 1 fonica
# 3 for
# 1 form
# 1 formelle
# 4 formular
# 1 formulare
# 1 formuliert
# 1 fortan
# 1 found
# 1 fpuer
# 2 frage
# 44 fragen
# 1 fraglich
# 1 fragt
# 2 fragte
# 2 frau
# 1 frec
# 1 frecherweise
# 9 frechheit
# 1 frechheiten
# 12 frei
# 1 freie
# 1 freien
# 2 freier
# 2 freigabe
# 1 freigabedaten
# 1 freigegeben
# 1 freigeschalten
# 25 freigeschaltet
# 1 freigibt
# 1 freihalten
# 1 freischalt
# 1 freischaltedauer
# 7 freischalten
# 2 freischaltet
# 6 freischalttermin
# 71 freischaltung
# 2 freischaltungstermin
# 1 freischaltungstermine
# 1 freischaltungsvorgang
# 1 freischaltungszeitraum
# 1 freistellung
# 5 freitag
# 1 freizuschalten
# 1 fremdfirma
# 2 fremdnetzen
# 1 fremdrouter
# 1 freschaltung
# 1 freude
# 1 freund
# 1 freunden
# 1 freundlche
# 135 freundlich
# 73 freundliche
# 7 freundlichen
# 1 freundlichenund
# 39 freundlicher
# 1 freundlicherweise
# 12 freundliches
# 40 freundlichkeit
# 1 freundluche
# 1 freunldich
# 1 freunldiche
# 2 freunlich
# 1 freunlichem
# 1 freunlicher
# 3 frieden
# 1 frist
# 1 fristen
# 1 fristgemaess
# 1 fristgemaesse
# 8 fristgerecht
# 1 fristgerechte
# 1 fristgerechten
# 1 fristsetzung
# 4 fritz
# 7 fritzbox
# 1 fritzboxen
# 2 froh
# 1 frohe
# 3 from
# 2 frueh
# 1 fruehe
# 8 frueher
# 1 fruehere
# 1 frust
# 1 fuctionierenden
# 1 fuehlt
# 1 fuehlte
# 1 fuehren
# 1 fuehrt
# 5 fuehrte
# 2 fuenf
# 1 fuenfte
# 181 fuer
# 1 fuerchterlich
# 1 fuerchterliche
# 3 fuers
# 1 fuersine
# 1 fuerstlichen
# 1 fuktioniert
# 1 fulfilled
# 1 functions
# 1 funksion
# 1 funkstick
# 1 funkstille
# 1 funkt
# 5 funktion
# 1 funktionalitaet
# 1 funktionen
# 1 funktionert
# 9 funktionieren
# 2 funktionierenden
# 2 funktionierender
# 2 funktionierendes
# 140 funktioniert
# 25 funktionierte
# 2 funktionierten
# 1 funktionsfaehigkeit
# 1 funktionsstoerungen
# 1 funzt
# 1 furchtbar
# 1 furchtbare
# 44 gab
# 2 gaebe
# 1 gang
# 17 ganz
# 12 ganze
# 16 ganzen
# 1 gap
# 66 gar
# 1 garantie
# 2 garantiert
# 1 garantierte
# 1 garnicht
# 6 garnichts
# 1 gasagt
# 3 gb
# 6 geaendert
# 1 geaergert
# 1 gealtert
# 3 geantwortet
# 5 gearbeitet
# 14 geben
# 1 gebessert
# 3 gebeten
# 1 gebiet
# 1 gebiete
# 5 geblieben
# 1 gebohrt
# 1 geboten
# 1 gebotene
# 5 gebracht
# 1 gebrauch
# 6 gebraucht
# 2 gebucht
# 5 gebuchte
# 1 gebuchten
# 6 gebuehr
# 7 gebuehren
# 6 gebunden
# 1 gechancelt
# 1 gedacht
# 1 gedauer
# 2 gedauerd
# 57 gedauert
# 1 gedrosselt
# 4 geduld
# 1 gedulden
# 3 geduldig
# 2 geduldige
# 1 geeigneter
# 1 gefaelligst
# 8 gefaellt
# 46 gefallen
# 3 gefaxt
# 1 gefehlt
# 1 gefiel
# 1 gefordert
# 3 gefragt
# 4 gefuehl
# 2 gefuehlt
# 3 gefuehrt
# 8 gefunden
# 9 gegangen
# 1 gegeangen
# 12 gegeben
# 1 gegebenheiten
# 1 gegend
# 7 gegensatz
# 5 gegenueber
# 1 geglaubt
# 1 gegriffen
# 16 gehabt
# 13 gehalten
# 1 gehaltenm
# 1 gehandelt
# 1 gehangen
# 4 gehe
# 7 gehen
# 1 gehoerige
# 7 gehoert
# 15 geholfen
# 1 geholt
# 23 geht
# 1 geiz
# 1 gekaempft
# 2 gekappt
# 7 geklaert
# 1 geklapppt
# 117 geklappt
# 1 geklapt
# 1 gekoedert
# 1 gekommem
# 42 gekommen
# 7 gekostet
# 17 gekuemmert
# 17 gekuendigt
# 1 gekuendigten
# 1 gelaende
# 1 gelaeutet
# 2 gelang
# 6 gelassen
# 22 gelaufen
# 17 geld
# 1 gelegen
# 1 gelegendliche
# 1 gelegenheit
# 1 gelegentliche
# 4 gelegt
# 2 geleistet
# 2 gelernt
# 2 gelesen
# 20 geliefert
# 3 gelieferte
# 1 gelieferten
# 1 geloescht
# 11 geloest
# 1 gelohnt
# 5 gelungen
# 27 gemacht
# 1 gemeinsame
# 10 gemeldet
# 1 gemessen
# 1 gemieteten
# 1 gemuet
# 1 gen
# 2 genannt
# 4 genannte
# 2 genannten
# 10 genau
# 6 genaue
# 2 genauen
# 1 genauer
# 1 genaueres
# 2 genauso
# 1 generell
# 1 genervt
# 21 genommen
# 1 genommmen
# 5 genug
# 1 geoeffnete
# 1 geopfert
# 4 gepasst
# 2 geplant
# 1 geplanten
# 1 geplatzter
# 3 geprueft
# 4 gerade
# 3 geraet
# 14 geraete
# 1 geraeten
# 1 geraetsversand
# 1 geraten
# 2 gerechnet
# 1 geredet
# 1 geregelt
# 1 gerettet
# 1 gerichtet
# 1 geringe
# 1 geringer
# 1 geringerer
# 4 gern
# 11 gerne
# 1 geruehrt
# 2 gerufen
# 11 gesagt
# 1 gesammelt
# 1 gesamt
# 4 gesamte
# 1 gesamten
# 5 gesamtpaket
# 1 geschadet
# 2 geschaeft
# 1 geschaeftsleitung
# 6 geschafft
# 1 geschaft
# 1 geschallten
# 2 geschalten
# 35 geschaltet
# 1 geschehen
# 1 gescheiterte
# 1 geschenk
# 1 geschichten
# 16 geschickt
# 1 geschlagen
# 2 geschlagene
# 2 geschlossen
# 1 geschmiert
# 1 geschoben
# 2 geschrieben
# 1 geschuldeten
# 1 geschult
# 1 geschulte
# 1 geschultes
# 2 geschweige
# 34 geschwindigkeit
# 1 geschwindigkeiten
# 1 geschwindigkeitsrate
# 1 geschworen
# 2 gesehen
# 2 gesendet
# 1 gesendete
# 4 gesetzt
# 1 gesichtspunkten
# 2 gespannt
# 1 gesplittet
# 13 gespraech
# 4 gespraeche
# 4 gespraechen
# 2 gespraechspartner
# 2 gespraechspartnern
# 1 gesprech
# 2 gesprochen
# 1 gestalten
# 2 gestaltet
# 1 geste
# 19 gestellt
# 2 gestellten
# 3 gestern
# 1 gestiegen
# 3 gestimmt
# 5 gesucht
# 3 getaetigt
# 1 getaetigten
# 1 getan
# 1 getauscht
# 1 getroestet
# 4 gewaehlt
# 1 gewaehlten
# 1 gewaehrleisten
# 3 gewaehrt
# 24 gewartet
# 3 gewechselt
# 2 gewinnen
# 1 gewinnmaximierung
# 1 gewissen
# 1 gewitter
# 3 gewohnt
# 1 gewollt
# 1 geworden
# 1 gewordene
# 1 geworfen
# 1 gewuenschent
# 5 gewuenscht
# 5 gewuenschte
# 1 gewuenschtem
# 9 gewuenschten
# 1 gewuenschter
# 1 gewust
# 2 gezeigt
# 2 gezwungen
# 1 ggf
# 1 ggfs
# 30 gibt
# 1 gibts
# 1 gigaset
# 92 ging
# 2 ginge
# 1 glasfaser
# 1 glasfaserkabel
# 2 glaube
# 12 gleich
# 3 gleiche
# 5 gleichen
# 1 gleis
# 1 gliche
# 2 glueck
# 1 gluecklicher
# 3 gluecklicherweise
# 1 gmx
# 1 good
# 2 google
# 1 grad
# 1 grade
# 2 gratis
# 1 grauenhaft
# 1 grauer
# 1 graus
# 1 greift
# 1 grenzen
# 1 grenzwertig
# 1 grevenbroich
# 3 griff
# 1 grob
# 1 groben
# 2 groessere
# 1 groesseren
# 1 groesserer
# 1 groesseres
# 2 groesste
# 1 groessten
# 1 groessteneils
# 2 groesstenteils
# 2 gross
# 15 grosse
# 1 grossem
# 5 grossen
# 2 grosser
# 2 grosses
# 1 grosskunden
# 1 grottig
# 1 gruende
# 3 gruenden
# 1 gruesse
# 2 gruessen
# 15 grund
# 3 grundgebuehr
# 1 gruss
# 2 gucken
# 12 guenstig
# 1 guenstige
# 2 guenstigen
# 9 guenstiger
# 3 guenstigere
# 1 guenstigeren
# 5 guenstiges
# 1 guenstigste
# 252 gut
# 149 gute
# 2 gutem
# 8 guten
# 87 guter
# 19 gutes
# 3 gutgeschrieben
# 1 gutgeschriebenen
# 3 guthaben
# 3 gutschein
# 16 gutschrift
# 6 gutschriften
# 1 gutschriftserteilung
# 1 gzt
# 1 habt
# 1 hack
# 1 hackt
# 1 had
# 1 haeaete
# 2 haelfte
# 2 haelt
# 1 haende
# 2 haengen
# 3 haengt
# 30 haette
# 8 haetten
# 1 haeufen
# 1 haeufig
# 1 haeufige
# 1 haeufigem
# 1 haeufiger
# 1 halb
# 4 halbe
# 4 halben
# 3 halbes
# 1 halbwissen
# 1 halfen
# 2 hallo
# 1 hals
# 2 halt
# 3 halten
# 1 hammer
# 5 hand
# 3 handeln
# 1 handelt
# 1 handelte
# 1 handhaben
# 2 handhabung
# 6 handy
# 1 handyanrufe
# 1 handyempfang
# 1 handykosten
# 1 handynetz
# 1 hansenet
# 1 happen
# 1 happens
# 1 happy
# 1 har
# 2 hard
# 48 hardware
# 1 hardwarepreise
# 1 hardwaretausch
# 1 hardwareversand
# 1 hartnaeckigkeit
# 1 has
# 2 hats
# 2 hatt
# 1 haufen
# 1 hauptschuld
# 1 hauptstadt
# 10 haus
# 2 hausanschluss
# 7 hause
# 1 hausfrauen
# 1 hausinterne
# 3 hausnummer
# 1 have
# 1 hd
# 1 heilig
# 1 heissen
# 6 heisst
# 1 heiterem
# 20 helfen
# 1 helpdesk
# 11 her
# 1 herabgelassen
# 1 herablassend
# 1 heran
# 5 heraus
# 1 herausfinden
# 1 herausgabe
# 1 herausgeben
# 1 herausgestellt
# 1 herausstellen
# 1 herausstellte
# 1 herauszuheben
# 1 herbeizufuehren
# 1 herein
# 3 hergestellt
# 1 herren
# 1 herrn
# 1 herstellen
# 1 hersteller
# 3 herstellung
# 1 hertelefoniererei
# 1 herueber
# 1 herum
# 1 hervorgetan
# 6 hervorragend
# 1 hervorragende
# 2 hervorzuheben
# 1 herzustellen
# 2 heut
# 67 heute
# 5 heutigen
# 1 heutzutage
# 1 hex
# 1 hick
# 1 hieran
# 1 hierdurch
# 2 hierfuer
# 2 hierher
# 1 hies
# 1 hiesigen
# 5 hiess
# 2 hilfbereit
# 45 hilfe
# 1 hilfehotline
# 1 hilfen
# 1 hilfenahme
# 3 hilfestellung
# 2 hilfestellungen
# 1 hilfetelefonate
# 1 hilflosigkeit
# 8 hilfreich
# 4 hilfreiche
# 1 hilfreichen
# 1 hilfreicher
# 2 hilfsbereich
# 40 hilfsbereit
# 11 hilfsbereite
# 4 hilfsbereiter
# 2 hilfsbereites
# 7 hilfsbereitschaft
# 1 hilfsmoeglichkeiten
# 1 hilfsreich
# 3 hilft
# 1 himmel
# 2 hinaus
# 1 hinbekam
# 2 hinbekommen
# 1 hinblick
# 2 hinfaellig
# 3 hing
# 2 hingegen
# 2 hingehalten
# 1 hingehauen
# 1 hingenommen
# 3 hingezogen
# 1 hinhaltetaktik
# 1 hinnehmen
# 1 hinschicken
# 1 hinsicht
# 2 hinterher
# 1 hinterhertelefonieren
# 1 hinterherzurennen
# 1 hinterlegen
# 3 hinterlegt
# 1 hinweg
# 3 hinweis
# 1 hinzubekommen
# 1 hinzubuchen
# 1 hmmm
# 10 hoch
# 1 hoechsten
# 1 hoechstens
# 1 hoefflicher
# 4 hoeflich
# 2 hoefliche
# 1 hoeflicher
# 1 hoeflichkeit
# 3 hoehe
# 4 hoeher
# 3 hoehere
# 1 hoeren
# 1 hoerten
# 5 hoffe
# 1 hoffen
# 2 hoffentlich
# 5 hohe
# 1 hohen
# 1 hoher
# 1 hohes
# 1 hold
# 1 holen
# 3 holprig
# 1 home
# 1 homepage
# 1 horrible
# 1 horror
# 1 hot
# 199 hotline
# 3 hotlinemitarbeiter
# 1 hotlinenummer
# 1 hotlinepersonal
# 2 hotlines
# 1 hotspot
# 1 ht
# 1 hw
# 1 hybriden
# 1 ibd
# 1 ice
# 1 ideal
# 1 idee
# 1 identifizieren
# 1 identisch
# 1 ie
# 1 iformation
# 1 ige
# 1 iger
# 1 ignored
# 1 ignorieren
# 4 ignoriert
# 1 ihem
# 1 ihrereseits
# 161 immer
# 5 immerhin
# 6 immernoch
# 1 immerueber
# 1 imperium
# 2 inakzeptabel
# 8 inbetriebnahme
# 1 inbetriebnehmer
# 2 incl
# 2 indicating
# 1 indiskutabel
# 21 info
# 1 infomail
# 28 information
# 35 informationen
# 1 informations
# 7 informationsfluss
# 1 informationshotline
# 1 informationspolitik
# 1 informationsservice
# 2 informativ
# 2 informieren
# 25 informiert
# 13 infos
# 1 inhalt
# 1 inhaltlich
# 6 inkl
# 1 inkompentente
# 4 inkompetent
# 7 inkompetente
# 1 inkompetenten
# 2 inkompetenter
# 2 inkompetentes
# 3 inkompetenz
# 1 inkorrekt
# 1 inkraft
# 1 innen
# 28 innerhalb
# 1 insatllation
# 4 insbesondere
# 1 insbesonders
# 12 insgesamt
# 1 instabil
# 7 instalation
# 1 instalations
# 1 instalationsservice
# 2 instalieren
# 1 instaliert
# 71 installation
# 2 installationsanleitung
# 1 installationsanleitungen
# 1 installationsanweisungen
# 2 installationscode
# 1 installationshilfe
# 2 installationsproblem
# 2 installationsservice
# 1 installationstag
# 3 installationstermin
# 1 installationsunterlagen
# 1 installierbar
# 13 installieren
# 3 installiert
# 1 instead
# 1 integriertes
# 1 intensiv
# 1 interessant
# 1 interessanterweise
# 1 interesse
# 1 interessen
# 1 interessieren
# 4 interessiert
# 2 intern
# 5 interne
# 3 internen
# 169 internet
# 11 internetanschluss
# 1 internetanschlusses
# 1 internetauftritt
# 1 internetbestellung
# 2 internetbox
# 1 internetempfang
# 1 internetflat
# 2 internetgeschwindigkeit
# 2 internetleitung
# 1 internetqualitaet
# 5 internets
# 1 internetseite
# 1 internetseiten
# 1 internetstick
# 1 internetsticks
# 1 internettechnik
# 1 internettelefonie
# 11 internetverbindung
# 1 internetvertrag
# 5 internetzugang
# 2 internetzugangs
# 1 intervention
# 1 intrernet
# 2 intresse
# 1 inzwischen
# 4 ip
# 1 irgend
# 2 irgendeine
# 1 irgendeiner
# 6 irgendwann
# 2 irgendwie
# 1 ironie
# 1 irrefuehrend
# 10 is
# 3 isdn
# 5 it
# 30 ja
# 1 jaben
# 1 jaehrige
# 14 jahr
# 11 jahre
# 1 jahrelang
# 7 jahren
# 1 jahreslos
# 1 jahresurlaub
# 1 jammer
# 6 januar
# 2 je
# 1 jedenfall
# 1 jedenfalls
# 12 jederzeit
# 1 jederzeitige
# 5 jedesmal
# 34 jedoch
# 2 jegliche
# 1 jehobt
# 11 jemand
# 3 jemanden
# 1 jetzige
# 2 jetzigen
# 1 jetziger
# 1 jeweils
# 1 jmd
# 2 job
# 1 jungen
# 6 juni
# 1 junli
# 1 kabale
# 6 kabel
# 1 kabelanschlusses
# 1 kabelsalat
# 1 kaeme
# 1 kalkulation
# 99 kam
# 6 kamen
# 2 kamm
# 1 kammen
# 1 kannte
# 1 kapazitaeten
# 1 karneval
# 1 karnevalsverein
# 3 karte
# 1 kasse
# 1 kassieren
# 2 kasten
# 3 katastrophal
# 1 katastrophalen
# 22 katastrophe
# 2 kauf
# 8 kaufen
# 1 kaufgeraets
# 1 kaufmaennische
# 5 kaum
# 1 kaution
# 1 kautions
# 2 kb
# 7 kbit
# 1 kbt
# 23 keinerlei
# 1 keineswegs
# 1 keinn
# 1 keins
# 2 keinster
# 2 keller
# 2 kenne
# 2 kennen
# 1 kenntnis
# 1 kenntniss
# 1 kenntnissen
# 2 kennwoerter
# 1 ketzt
# 1 kinden
# 1 kinder
# 2 kinderleicht
# 3 kinderspiel
# 5 klaeren
# 1 klaerung
# 1 klagen
# 2 klappen
# 8 klappt
# 8 klappte
# 10 klar
# 7 klare
# 2 klarer
# 1 klarheit
# 7 klasse
# 6 kleine
# 5 kleinen
# 2 kleiner
# 3 kleines
# 1 kleingedruckten
# 1 kleinigkeiten
# 1 klemmenplan
# 1 kling
# 1 klingel
# 1 km
# 8 knapp
# 1 knie
# 2 know
# 1 knowhow
# 1 kochbuch
# 1 koeche
# 1 koeln
# 1 koenig
# 5 koenne
# 38 koennen
# 9 koennte
# 2 koennten
# 1 koerperverletzung
# 1 kollege
# 4 kollegen
# 1 kolumne
# 1 kom
# 1 kombi
# 1 komepetent
# 1 kometent
# 2 komisch
# 1 komlikationslos
# 1 komme
# 28 kommen
# 1 kommentar
# 1 kommmt
# 28 kommt
# 1 kommunikat
# 52 kommunikation
# 1 kommunikationinnerhalb
# 1 kommunikationsprobleme
# 1 kommunikationsteilnehmer
# 1 kommunikstion
# 1 kommuniziert
# 2 kompakt
# 1 kompatibel
# 1 kompertiepel
# 1 kompetend
# 56 kompetent
# 50 kompetente
# 6 kompetenten
# 17 kompetenter
# 1 kompetentes
# 19 kompetenz
# 1 kompetnz
# 1 kompletpaket
# 15 komplett
# 1 komplettausfall
# 4 komplette
# 1 kompletter
# 1 komplexe
# 7 komplikationen
# 3 kompliziert
# 3 komplizierte
# 1 komplizierter
# 1 kompliziertes
# 1 kompotente
# 1 kompromiss
# 3 komunikation
# 1 konakte
# 1 kondition
# 4 konditionen
# 2 konfiguration
# 1 konfigurationscode
# 2 konfigurieren
# 1 konfiguriert
# 1 konfus
# 1 konkrete
# 1 konkreten
# 1 konkurenz
# 1 konkurrent
# 1 konkurrenten
# 5 konkurrenz
# 71 konnte
# 8 konnten
# 1 konsequenz
# 1 konstant
# 1 konstante
# 1 konsultieren
# 2 kontackt
# 48 kontakt
# 13 kontaktaufnahme
# 2 kontakte
# 2 kontaktformular
# 2 kontaktieren
# 2 kontaktiert
# 1 kontaktierte
# 1 kontaktnummer
# 1 kontinuierliche
# 12 konto
# 1 kontra
# 2 konzern
# 1 konzipierte
# 1 kooennte
# 2 kooperation
# 2 kooperativ
# 1 kooperieren
# 1 koordination
# 1 koordiniert
# 1 kopie
# 1 korekt
# 2 korekte
# 7 korrekt
# 6 korrekte
# 1 korrekten
# 1 korrektur
# 1 korriereiren
# 2 korrigieren
# 2 korrigiert
# 1 koste
# 24 kosten
# 1 kostenanteil
# 1 kostenaufstellung
# 1 kostenfrage
# 4 kostenfrei
# 11 kostenfreie
# 1 kostenguenstig
# 29 kostenlos
# 69 kostenlose
# 5 kostenlosen
# 5 kostenloser
# 1 kostenloses
# 1 kostenpflichtig
# 1 kostenpflichtigen
# 1 kostet
# 1 kostete
# 1 kraefte
# 2 kraehe
# 1 krank
# 1 kriegen
# 1 kritisieren
# 2 kroenung
# 1 kroke
# 1 kuemmere
# 5 kuemmern
# 6 kuemmert
# 1 kuemmerte
# 14 kuendigen
# 34 kuendigung
# 1 kuendigungfristen
# 2 kuendigungsbestaetigung
# 8 kuendigungsfrist
# 1 kuendigungsschreiben
# 2 kuendigungstermin
# 1 kuendigungszeit
# 1 kuendigungszeitpunkt
# 1 kuendigunmgen
# 1 kuerze
# 1 kulant
# 4 kulanz
# 1 kulanzregelung
# 28 kunde
# 1 kundecenters
# 33 kunden
# 1 kundenaccount
# 1 kundenakte
# 1 kundenanliegen
# 1 kundenbearbeitung
# 3 kundenberater
# 1 kundenberatern
# 7 kundenberatung
# 6 kundenbetreuer
# 1 kundenbetreuerin
# 1 kundenbetreung
# 21 kundenbetreuung
# 6 kundencenter
# 16 kundendienst
# 7 kundenfreundlich
# 2 kundenfreundliche
# 1 kundenfreundlichen
# 1 kundenfreundlicher
# 5 kundenfreundlichkeit
# 1 kundengespraeche
# 2 kundenhotline
# 2 kundenkontakt
# 2 kundenorientiert
# 1 kundenorientiertes
# 1 kundenorientiertheit
# 2 kundenorientierung
# 2 kundenportal
# 63 kundenservice
# 1 kundenservicehotline
# 1 kundenservices
# 1 kundenserviece
# 4 kundensupport
# 3 kundenzufriedenheit
# 1 kundenzusammenarbeit
# 10 kurz
# 1 kurzanleitung
# 10 kurze
# 1 kurzem
# 1 kurzen
# 3 kurzer
# 7 kurzfristig
# 1 kurzfristigen
# 1 kurzfristiger
# 1 laaange
# 5 laden
# 1 laecherliche
# 3 laege
# 1 laendlichen
# 1 laendlicher
# 1 laenge
# 9 laenger
# 3 laengere
# 1 laengeren
# 2 laengst
# 10 laesst
# 1 laestig
# 37 laeuft
# 8 lag
# 10 lage
# 1 lagen
# 1 lahm
# 1 lahmgelegt
# 4 laien
# 11 lan
# 3 land
# 1 lande
# 1 landet
# 18 lang
# 136 lange
# 2 langem
# 7 langen
# 4 langer
# 2 langes
# 1 langjaehrige
# 12 langsam
# 9 langsame
# 3 langsamer
# 6 langsames
# 2 langwierige
# 1 langwierigen
# 1 langwieriger
# 1 lapidar
# 1 lapidarer
# 1 laptop
# 1 lass
# 1 lasse
# 17 lassen
# 1 lastschriftrueckbuchung
# 9 laufen
# 1 laufend
# 1 laufende
# 2 laufenden
# 1 lauferei
# 3 laufzeit
# 6 laut
# 1 layout
# 4 leben
# 8 lediglich
# 3 leere
# 1 leeren
# 1 lege
# 2 legen
# 1 lehnen
# 11 leicht
# 4 leichte
# 1 leichtes
# 1 leid
# 99 leider
# 1 leidet
# 1 leidtragende
# 1 leiert
# 3 leisten
# 59 leistung
# 14 leistungen
# 3 leistungs
# 1 leistungsdaten
# 1 leistungsmoeglichkeiten
# 1 leistungsumfang
# 12 leistungsverhaeltnis
# 1 leisungs
# 1 leiten
# 1 leiter
# 1 leitumg
# 80 leitung
# 4 leitungen
# 1 leitungsgeschwindigkeit
# 1 leitungshoheit
# 1 leitungsinstallation
# 1 leitungsmangel
# 1 leitungsprobleme
# 1 leitungsqualitaet
# 2 leitungsstoerung
# 1 leitungsverbindung
# 1 leitungsverspaetung
# 1 lernen
# 2 lesen
# 1 letzt
# 9 letzte
# 4 letzten
# 9 letztendlich
# 1 letztenendes
# 1 letztens
# 1 letzter
# 7 letztlich
# 12 leute
# 1 lg
# 6 lieber
# 42 lief
# 1 liefen
# 1 lieferbar
# 7 liefern
# 1 lieferstatusses
# 2 liefert
# 1 liefertermin
# 37 lieferung
# 2 lieferzeit
# 1 lieferzeiten
# 2 liegen
# 9 liegt
# 2 liess
# 2 line
# 5 linke
# 2 loben
# 7 loesen
# 12 loesung
# 3 loesungen
# 3 lt
# 9 lte
# 5 ma
# 3 mache
# 14 macht
# 2 machte
# 5 maerz
# 8 magenta
# 3 mai
# 38 mail
# 6 mails
# 82 mal
# 3 male
# 2 maliger
# 7 manchmal
# 2 mangel
# 7 mangelhaft
# 2 mangelnde
# 5 mann
# 2 masslos
# 5 max
# 5 maximal
# 5 mb
# 34 mbit
# 2 mbits
# 2 meckern
# 3 media
# 67 mehr
# 21 mehrere
# 10 mehreren
# 12 mehrfach
# 4 mehrfache
# 2 mehrfachen
# 2 mehrfacher
# 2 mehrmalige
# 3 mehrmaligem
# 6 mehrmaligen
# 2 mehrmaliger
# 14 mehrmals
# 8 meinerseits
# 2 meinte
# 4 meinung
# 1 meinvodafone
# 7 meist
# 3 meiste
# 1 meisten
# 2 meistens
# 5 melden
# 1 meldet
# 2 meldete
# 2 meldung
# 3 menge
# 1 mensch
# 5 menschen
# 8 mfg
# 1 mietarbeiter
# 2 miete
# 1 mietgeraet
# 1 mietgeraete
# 12 min
# 4 mind
# 5 mindestens
# 1 minimalen
# 1 minimiert
# 1 minimum
# 2 minute
# 21 minuten
# 1 minutenlange
# 1 miserabel
# 1 miserable
# 1 miserabler
# 1 misere
# 1 missfallen
# 1 misslang
# 1 missverstaendnise
# 1 missverstaendnissen
# 1 mist
# 1 mitaebeiter
# 1 mitarbeier
# 180 mitarbeiter
# 8 mitarbeiterin
# 5 mitarbeiterinnen
# 14 mitarbeitern
# 2 mitbewerbern
# 22 mitgeteilt
# 2 mitlerweile
# 3 mitnahme
# 2 mitnehmen
# 8 mitte
# 2 mitteilen
# 7 mitteilung
# 3 mitten
# 4 mittlerweile
# 3 mitzuteilen
# 2 mobiles
# 21 modem
# 5 modems
# 3 moechte
# 45 moeglich
# 10 moeglichkeit
# 2 moeglichkeiten
# 2 moin
# 2 moment
# 2 momentan
# 40 monat
# 102 monate
# 45 monaten
# 2 monatige
# 2 monatiger
# 2 monatliche
# 3 monatlichen
# 2 montage
# 7 monteur
# 2 morgen
# 2 ms
# 6 muehe
# 22 muessen
# 12 muesste
# 2 munter
# 2 musik
# 13 mussten
# 3 my
# 3 na
# 25 nachdem
# 29 nachfrage
# 16 nachfragen
# 4 nachgefragt
# 6 nachhinein
# 2 nachmittag
# 3 nachricht
# 2 nacht
# 2 nachtraegliche
# 2 nachvollziehbar
# 2 naechste
# 13 naechsten
# 2 naechster
# 2 naechstes
# 4 naemlich
# 2 nah
# 2 nahmen
# 2 namen
# 9 natuerlich
# 2 ncihts
# 2 ne
# 3 neben
# 15 negativ
# 2 negative
# 4 negatives
# 10 nehmen
# 3 nein
# 4 nen
# 3 nennen
# 8 nerven
# 25 nett
# 40 nette
# 25 netter
# 4 nettes
# 17 netz
# 3 netzqualitaet
# 17 neu
# 3 neuanschluss
# 21 neue
# 36 neuen
# 6 neuer
# 4 neues
# 3 nich
# 54 nie
# 2 niedriger
# 2 niemals
# 15 niemand
# 2 niemanden
# 3 nimmt
# 14 nix
# 7 nochmal
# 2 nochmals
# 7 noetig
# 2 noetigen
# 4 normal
# 2 normalen
# 2 not
# 2 nothing
# 7 notwendig
# 3 notwendigen
# 7 november
# 7 nr
# 2 number
# 19 nummer
# 2 nummern
# 2 nutzbar
# 17 nutzen
# 7 nutzung
# 2 oben
# 49 obwohl
# 2 oefter
# 1 of
# 1 offen
# 1 offenbar
# 1 offene
# 1 offenkundig
# 1 offensichtlich
# 1 offer
# 1 offiziell
# 11 oft
# 1 oftmals
# 1 og
# 35 ok
# 1 oktober
# 3 on
# 35 online
# 2 onlineportal
# 1 onlineshop
# 3 only
# 1 operativ
# 1 operator
# 1 opfern
# 1 optimal
# 1 option
# 3 or
# 1 order
# 1 ordering
# 1 ordern
# 23 ordnung
# 2 ordnungsgemaess
# 1 organisation
# 1 organisatorisch
# 3 organisiert
# 1 orientiert
# 26 ort
# 1 orts
# 1 other
# 15 paar
# 1 paasiert
# 1 package
# 3 packet
# 1 packete
# 8 paket
# 1 paketes
# 1 paketpreis
# 1 pakets
# 1 panen
# 1 panne
# 2 pannen
# 1 paper
# 1 papier
# 1 papiere
# 2 papierkram
# 1 parameter
# 1 parat
# 1 parteien
# 2 partner
# 1 partnerinnen
# 1 pasiert
# 2 passend
# 4 passieren
# 14 passiert
# 2 passierte
# 1 passt
# 1 passwoerter
# 1 passwort
# 1 patzig
# 1 pauschal
# 1 pause
# 2 pay
# 2 pc
# 1 pdf
# 1 pech
# 1 pechgehabt
# 66 per
# 13 perfekt
# 5 perfekte
# 3 performance
# 1 permanenten
# 1 persoehnlichen
# 5 persoenlich
# 10 persoenliche
# 2 persoenlichem
# 2 persoenlichen
# 6 persoenlicher
# 1 persoenlichkeit
# 6 person
# 18 personal
# 3 personen
# 1 persos
# 1 phase
# 1 phrasen
# 1 physikalisch
# 1 pin
# 3 ping
# 1 pizaa
# 3 plan
# 1 planlos
# 1 platzen
# 1 playstation
# 2 ploetzlich
# 4 plus
# 1 pluspunkt
# 2 portal
# 1 portieren
# 11 portierung
# 1 portierungauftrag
# 1 portierungsanfrage
# 11 portierungsauftrag
# 2 portierungskosten
# 1 portierungsproblem
# 1 portierungsunterlagen
# 2 ports
# 1 pos
# 13 positiv
# 2 positive
# 1 positiven
# 5 positives
# 11 post
# 1 postalisch
# 1 postalischer
# 1 posten
# 1 postives
# 1 postsendungen
# 1 poststreik
# 2 power
# 1 powerline
# 2 praemie
# 1 praemien
# 1 praesent
# 1 praezise
# 1 praktisch
# 1 prei
# 80 preis
# 9 preise
# 1 preisgarantie
# 1 preisguenstigeren
# 1 preisleisleistung
# 1 preisleistungsverhaeltniss
# 1 preisleistungverhaeltnis
# 2 preislich
# 2 preisminderung
# 2 preisnachlass
# 1 preisrelation
# 1 preisverhaeltnis
# 1 preiswert
# 2 premium
# 1 premiumbereich
# 1 price
# 14 prima
# 1 prime
# 1 priorisierung
# 2 privaten
# 1 privatkunden
# 3 pro
# 1 probelamitk
# 1 probiert
# 47 problem
# 1 problematik
# 4 problematisch
# 1 problembebung
# 2 problembehandlung
# 1 problembehebung
# 1 problembeseitigung
# 1 problemchen
# 142 probleme
# 37 problemen
# 1 problemfreier
# 1 problemloese
# 1 problemloesen
# 8 problemloesung
# 65 problemlos
# 22 problemlose
# 3 problemloser
# 2 problemloses
# 4 problems
# 1 problemslos
# 1 proboeemlos
# 10 produkt
# 3 produkte
# 1 produktes
# 1 produktleistung
# 1 produktpalette
# 5 professionell
# 3 professioneller
# 2 professionelles
# 1 programmieren
# 1 programmiert
# 1 programmierung
# 1 projekt
# 1 promised
# 4 prompt
# 6 prompte
# 1 prompter
# 1 promt
# 4 promte
# 1 promter
# 1 propleme
# 1 protierung
# 1 provided
# 9 provider
# 1 providers
# 1 providerwechsel
# 1 provieder
# 1 prozedur
# 1 prozess
# 4 prozesse
# 1 prozesses
# 1 prpblem
# 2 pruefen
# 1 prueftermin
# 1 pruefung
# 1 ps
# 1 puecklichkeit
# 1 puenklich
# 2 puenkliche
# 49 puenktlich
# 23 puenktliche
# 4 puenktlicher
# 8 puenktlichkeit
# 1 punk
# 6 punkt
# 1 punkte
# 1 punkten
# 1 punktgenau
# 1 punktgenaue
# 1 punkto
# 1 punktzahl
# 1 pur
# 22 qualitaet
# 1 qualitaetssicherung
# 2 qualitet
# 2 quality
# 1 quasi
# 4 rabatt
# 4 rabatte
# 1 raeder
# 1 raedern
# 1 raeumlichkeiten
# 1 rahmen
# 1 ram
# 1 rand
# 2 rasch
# 3 rasche
# 2 raten
# 1 raum
# 7 raus
# 1 rauschen
# 1 rausgenommen
# 3 rausgeschickt
# 1 rausgeschmissen
# 1 rauskommen
# 1 rausstellen
# 1 rauszuwinden
# 1 rd
# 16 reagiert
# 18 reaktion
# 2 reaktionen
# 1 reaktionsschnelligkeit
# 1 reaktionszeit
# 1 reakton
# 1 realiesiert
# 1 realisierbar
# 2 realisieren
# 1 realisiert
# 1 realisierung
# 1 realistische
# 1 realistischer
# 5 receiver
# 1 recherche
# 1 rechner
# 41 rechnung
# 22 rechnungen
# 1 rechnungserstellung
# 1 rechnungsstellung
# 1 rechnungsstellungen
# 1 rechnungszustellung
# 16 recht
# 5 rechte
# 1 rechtlich
# 1 rechtsanwalt
# 1 rechtsberatung
# 1 rechtsgueltiger
# 1 rechtszeitig
# 1 rechtzeiti
# 10 rechtzeitig
# 4 rechtzeitige
# 1 rechtzeitiger
# 1 rechtzeitliche
# 1 rechung
# 1 recorsenmangrl
# 3 rede
# 1 redlich
# 1 reduziert
# 1 refund
# 2 regel
# 1 regelbar
# 5 regelmaessig
# 2 regelmaessige
# 1 regelmaessiger
# 1 regelrecht
# 1 regelung
# 2 regen
# 1 regine
# 1 regio
# 4 region
# 2 regional
# 1 registreieren
# 1 registrieren
# 1 registriert
# 3 registrierung
# 1 registrierungskey
# 1 regulaerpreis
# 1 regulierung
# 1 reibungloese
# 1 reibungsfrei
# 87 reibungslos
# 10 reibungslose
# 1 reibungslosen
# 13 reibungsloser
# 1 reichen
# 1 reichlich
# 3 reicht
# 3 rein
# 1 reine
# 1 reines
# 1 reinkommen
# 5 reklamation
# 3 reklamationen
# 1 reklamationsmanagement
# 1 reklamieren
# 32 relativ
# 1 relatv
# 1 relevanten
# 1 reneut
# 1 respektlos
# 2 rest
# 1 restaurant
# 1 restschuld
# 1 resultat
# 1 revidierte
# 20 richtig
# 5 richtige
# 4 richtigen
# 1 richtigstellungen
# 3 rief
# 1 riefen
# 1 riesenfrechheit
# 1 roboter
# 1 roboterstimme
# 1 rooter
# 1 rosenheim
# 1 routen
# 64 router
# 1 routern
# 1 routerns
# 8 routers
# 1 routr
# 1 rr
# 1 ruck
# 1 ruckizucki
# 1 rueckabwicklung
# 2 rueckantwort
# 1 rueckeufversprechen
# 2 rueckfrage
# 10 rueckfragen
# 1 rueckgaengig
# 1 rueckgangig
# 1 rueckkehr
# 9 rueckmeldung
# 1 rueckmeldungen
# 12 rueckruf
# 4 rueckrufe
# 2 rueckrufservice
# 1 ruecksendeschein
# 1 ruecksendescheine
# 3 ruecksprache
# 1 rueckverguetung
# 1 rueckzahlung
# 1 rufen
# 2 rufnr
# 15 rufnummer
# 3 rufnummermitnahme
# 1 rufnummern
# 6 rufnummernmitnahme
# 7 rufnummernportierung
# 1 rufnummernuebermahme
# 3 rufnummernuebernahme
# 1 rufnummerportierung
# 1 ruft
# 1 ruhen
# 2 rum
# 1 rumstreiten
# 7 rund
# 1 rundherum
# 2 rundum
# 2 runter
# 2 sachbearbeiter
# 1 sachbearbeiterin
# 1 sachbearber
# 5 sache
# 3 sachen
# 1 sachkenntnis
# 1 sachkundige
# 1 sachlich
# 1 sachliche
# 1 sachverhalt
# 1 saftladen
# 1 sag
# 23 sagen
# 5 sagt
# 9 sagte
# 1 sagten
# 1 sah
# 1 said
# 1 same
# 4 samstag
# 1 samstags
# 3 sat
# 1 sau
# 3 sauber
# 1 sauberer
# 1 sauer
# 1 sauladen
# 1 sbend
# 1 sch
# 13 schade
# 1 schadens
# 1 schaetze
# 1 schaetzen
# 3 schaffen
# 3 schafft
# 5 schalten
# 1 schalttag
# 5 schalttermin
# 1 schalttermine
# 30 schaltung
# 5 schaltungstermin
# 1 schande
# 2 schauen
# 1 schaun
# 1 schein
# 2 scheinbar
# 1 scheinen
# 4 scheint
# 1 schelcht
# 1 schell
# 1 schelle
# 1 schick
# 5 schicken
# 1 schicker
# 1 schieben
# 8 schief
# 4 schien
# 2 schildern
# 1 schilderte
# 1 schilderten
# 1 schilling
# 1 schlafmuetzenverein
# 1 schlagen
# 1 schlappe
# 1 schlechste
# 41 schlecht
# 32 schlechte
# 3 schlechten
# 23 schlechter
# 3 schlechtes
# 4 schlechteste
# 1 schlechtesten
# 2 schlechtester
# 1 schlechthin
# 1 schleichende
# 1 schleife
# 2 schleppende
# 1 schlichtes
# 2 schlichtweg
# 2 schliessen
# 3 schliesslich
# 1 schlimmeres
# 1 schlimmsten
# 1 schlosses
# 1 schludrig
# 4 schluss
# 1 schlussendlich
# 1 schmoren
# 1 schnel
# 1 schneligkeit
# 265 schnell
# 252 schnelle
# 2 schnellem
# 70 schneller
# 1 schnellere
# 1 schnelleren
# 1 schnellerer
# 6 schnelles
# 1 schnellichkeit
# 22 schnelligkeit
# 1 schnellr
# 1 schnellst
# 1 schnellsten
# 2 schnellstens
# 4 schnellstmoeglich
# 1 schnellstmoeglichen
# 1 schnoerkellos
# 1 schock
# 7 schoen
# 1 schoenes
# 37 schon
# 1 schonmal
# 1 schreibe
# 13 schreiben
# 1 schrieb
# 1 schriftgoesse
# 9 schriftlich
# 11 schriftliche
# 2 schriftlichen
# 1 schriftlicher
# 2 schriftverkehr
# 1 schriftwechsel
# 4 schritt
# 5 schritte
# 1 schritten
# 1 schrott
# 1 schublade
# 2 schufa
# 1 schufaeintrag
# 2 schuld
# 1 schuldlos
# 1 schuldzuweisung
# 1 schulnote
# 1 schwach
# 1 schwammige
# 1 schwankend
# 1 schwankende
# 2 schwankungen
# 2 schweigen
# 4 schwer
# 1 schwerer
# 8 schwierig
# 1 schwieriger
# 1 schwierigkeit
# 10 schwierigkeiten
# 1 schwimmbad
# 1 scrolls
# 1 sec
# 4 sechs
# 1 seconds
# 2 sehe
# 8 sehen
# 1 sehrgut
# 14 sei
# 2 seid
# 42 seit
# 6 seitdem
# 8 seite
# 7 seiten
# 1 seitenaufbau
# 22 seitens
# 1 seither
# 1 sekunden
# 1 selbe
# 2 selben
# 14 selber
# 1 selbigen
# 1 selbstinstallation
# 1 selbststaendige
# 1 selbststaendigen
# 1 selbstverstaendich
# 1 selbstverstaendlich
# 1 selbstverstaendnis
# 1 sendeleistung
# 1 sendemast
# 1 sendet
# 1 senken
# 1 sensationell
# 3 sent
# 1 sepa
# 1 seperate
# 1 sept
# 2 september
# 1 septemberwoche
# 1 sercice
# 1 serice
# 1 serioese
# 1 serrvice
# 1 serven
# 2 server
# 383 service
# 1 serviceabwicklung
# 1 serviceangestellten
# 4 servicecenter
# 2 servicedienst
# 13 servicehotline
# 2 serviceleistung
# 2 serviceleistungen
# 1 serviceleute
# 1 serviceleuten
# 13 servicemitarbeiter
# 1 servicemitarbeiters
# 6 servicenummer
# 1 servicenummern
# 1 serviceorientiert
# 4 servicepersonal
# 6 servicequalitaet
# 1 servicerufnummer
# 1 servicerufnummern
# 4 services
# 4 serviceteam
# 1 serviceteams
# 11 servicetechniker
# 1 servicetechnikern
# 3 servicetechnikers
# 3 servicetelefon
# 1 servicetermin
# 1 servicewueste
# 2 servicezentrale
# 1 servichotline
# 2 servis
# 1 servise
# 1 servive
# 1 serviveteam
# 1 setvicehotline
# 2 setzen
# 4 sevice
# 1 sevicezentrale
# 1 sgane
# 1 sher
# 3 shipment
# 1 shipped
# 1 shirt
# 2 shop
# 2 shops
# 1 should
# 1 sic
# 2 sicher
# 1 sicherheitsleistung
# 1 sicherheitspaket
# 1 sicherstellen
# 1 sicht
# 4 siehe
# 3 sieht
# 1 signal
# 1 signalstellung
# 1 signalstoerungen
# 1 silvio
# 2 sim
# 1 simpel
# 2 sinnlos
# 1 sinnlose
# 1 site
# 2 sitze
# 2 sitzen
# 2 sitzt
# 1 skandal
# 1 skeptisch
# 1 slber
# 1 slcht
# 1 slogan
# 1 slots
# 20 sms
# 1 smtp
# 1 snele
# 3 sobald
# 10 sodass
# 1 sofern
# 46 sofort
# 1 sofortbonus
# 1 soforthilfe
# 9 sofortige
# 1 sofortiger
# 2 sofortkennung
# 1 sofortkuendigungsrecht
# 1 sofortreaktion
# 2 software
# 1 softwarefehler
# 1 sog
# 23 sogar
# 1 sohn
# 1 soich
# 1 solala
# 3 solange
# 1 solide
# 5 solle
# 3 sollen
# 3 sollten
# 1 sometimes
# 14 somit
# 2 sonderkuendigung
# 2 sonderkuendigungsrecht
# 1 sonderkundigungsrecht
# 1 sonntag
# 1 sonstiges
# 1 sorglos
# 1 souveraenitaet
# 2 sowas
# 11 soweit
# 1 soweiter
# 12 sowie
# 5 sowohl
# 12 spaet
# 3 spaete
# 2 spaetem
# 53 spaeter
# 1 spaeterer
# 1 spaeterxerst
# 2 spaetestens
# 1 sparen
# 1 spass
# 6 speed
# 1 speedbox
# 1 speedcheck
# 4 speedport
# 1 speedprobleme
# 1 speter
# 2 speziell
# 2 speziellen
# 1 spied
# 1 spiegel
# 1 spielend
# 2 spinnt
# 2 spitze
# 1 spitzen
# 1 splitter
# 2 sprach
# 1 sprachkenntnisse
# 1 sprachqualitaet
# 1 sprachqualtaet
# 3 sprechen
# 1 sprich
# 3 spricht
# 1 spueren
# 2 spur
# 1 srevice
# 1 stabde
# 12 stabil
# 7 stabile
# 2 stabilen
# 2 stabiler
# 1 stabiles
# 2 stabilitaet
# 1 stadt
# 16 staendig
# 4 staendige
# 3 staendiges
# 1 stammen
# 21 stand
# 1 standard
# 1 standartvordrucke
# 18 stande
# 1 standfuss
# 2 standort
# 4 stark
# 2 start
# 2 starten
# 2 startguthaben
# 1 starttermins
# 1 stationen
# 14 statt
# 1 stattdem
# 2 stattdessen
# 2 statten
# 7 status
# 1 statusmeldungen
# 3 std
# 1 steckdose
# 1 stecker
# 1 steffen
# 4 stehe
# 6 stehen
# 11 steht
# 1 stein
# 1 steinmetz
# 3 stelle
# 7 stellen
# 1 stellend
# 2 stellt
# 4 stellte
# 1 stenlose
# 1 stete
# 11 stets
# 1 stichtag
# 5 stick
# 1 sticks
# 1 still
# 1 stille
# 1 stilllegen
# 1 stimme
# 1 stimmen
# 7 stimmt
# 2 stimmte
# 2 stinksauer
# 1 stockt
# 2 stoermeldung
# 20 stoerung
# 18 stoerungen
# 1 stoerungsanfaellig
# 3 stoerungsbehebung
# 1 stoerungsbeseitigung
# 3 stoerungsdienst
# 2 stoerungsfrei
# 1 stoerungshotline
# 3 stoerungsmeldung
# 1 stoerungsstelle
# 1 stolperfalle
# 2 stornieren
# 18 storniert
# 1 stornierte
# 6 stornierung
# 1 stornierungen
# 1 stornirt
# 1 storno
# 1 str
# 1 strano
# 2 strasse
# 1 streame
# 1 streichung
# 3 strich
# 1 strickt
# 2 strippe
# 1 stromanbieter
# 1 stromausfall
# 1 stromzufuhr
# 1 strukturen
# 1 stuck
# 1 stuerzte
# 6 stunde
# 20 stunden
# 3 stundenlang
# 1 stundenlange
# 1 stundenlanger
# 1 stundenlanges
# 2 sub
# 1 such
# 1 sucher
# 1 sueper
# 3 summe
# 104 super
# 1 superschnell
# 1 superschnelle
# 1 supi
# 1 supper
# 27 support
# 5 surf
# 4 surfen
# 1 surfgeschwindigkeit
# 1 surfsofortpaket
# 1 surfsofortstick
# 2 surfstick
# 1 surfsticks
# 1 swm
# 1 synchronisiert
# 5 system
# 1 systemfehler
# 1 systemmeldungen
# 1 systemproblem
# 6 tadellos
# 7 taeglich
# 1 taeglicher
# 1 taetigen
# 1 taeuschung
# 49 tag
# 53 tage
# 1 tagelang
# 1 tagelangem
# 23 tagen
# 1 tages
# 1 tageszeiten
# 1 tageweise
# 1 taggenau
# 16 tarif
# 1 tarifabschluss
# 4 tarife
# 2 tarifs
# 1 tarifschaltung
# 2 tarifwechsel
# 1 tatsache
# 8 tatsaechlich
# 2 tatsaechliche
# 1 tatsaechlichen
# 1 tatsaechlicher
# 4 team
# 1 teams
# 7 techn
# 1 technical
# 1 technich
# 1 technician
# 1 technicker
# 16 technik
# 1 technikabteilung
# 1 techniken
# 178 techniker
# 1 technikerankuendigung
# 2 technikereinsatz
# 1 technikerin
# 1 technikerkosten
# 1 technikern
# 3 technikers
# 1 technikerservice
# 6 technikertermin
# 4 technikertermine
# 2 technikhotline
# 19 technisch
# 22 technische
# 2 technischem
# 15 technischen
# 4 technischer
# 3 technisches
# 1 technisher
# 1 technologieumstellung
# 1 technologische
# 1 teen
# 9 teil
# 3 teile
# 5 teils
# 1 teilte
# 1 teilten
# 15 teilweise
# 13 tel
# 2 tele
# 9 telecom
# 3 telef
# 1 telefin
# 1 telefohn
# 166 telefon
# 3 telefonanbieter
# 11 telefonanschluss
# 1 telefonanschlusses
# 5 telefonat
# 18 telefonate
# 13 telefonaten
# 1 telefonberater
# 1 telefonberatung
# 1 telefonbuch
# 1 telefoncomputer
# 2 telefondose
# 1 telefone
# 2 telefonflat
# 1 telefongespraech
# 1 telefongespraechs
# 11 telefonhotline
# 1 telefonica
# 7 telefonie
# 18 telefonieren
# 1 telefonierens
# 9 telefoniert
# 38 telefonisch
# 43 telefonische
# 6 telefonischen
# 13 telefonischer
# 2 telefonkontakt
# 1 telefonkosten
# 6 telefonleitung
# 8 telefonnummer
# 3 telefonnummern
# 2 telefonqualitaet
# 14 telefonservice
# 2 telefonsupport
# 1 telefontechniker
# 1 telefonverbindungen
# 1 telefonwechsel
# 396 telekom
# 1 telekomanschluss
# 1 telekomhotline
# 1 telekomiker
# 1 telekomkundencenter
# 1 telekomleute
# 1 telekomm
# 1 telekommechaniker
# 1 telekommitarbeite
# 3 telekommitarbeiter
# 1 telekommunikationsanbieter
# 1 telekommunikationsunternehmen
# 1 telekomrechnung
# 1 telekomservice
# 1 telekomshop
# 5 telekomtechniker
# 1 telekomverteilung
# 1 telekomzugang
# 3 telkom
# 1 telkomservices
# 1 telnr
# 1 telrfon
# 2 temporaeren
# 1 ten
# 118 termin
# 3 terminabsprache
# 1 terminbestaetigung
# 44 termine
# 4 termineinhaltung
# 4 terminen
# 1 terminerinnerung
# 1 terminflexibilitaet
# 1 termingenau
# 1 termingenauer
# 15 termingerecht
# 7 termingerechte
# 1 termingerechter
# 1 termingetreue
# 1 terminhinweise
# 1 terminierung
# 2 terminliche
# 1 terminplanung
# 3 termins
# 2 termintreu
# 5 termintreue
# 3 terminvereinbarung
# 1 terminvereinbarungs
# 3 terminvergabe
# 1 terminverschiebung
# 1 terminversprechungen
# 1 terminwuensche
# 1 termkne
# 1 test
# 3 testen
# 1 tests
# 5 teuer
# 1 teuerer
# 1 teuersten
# 1 teure
# 3 teurer
# 1 teures
# 1 text
# 1 than
# 3 that
# 16 the
# 2 theater
# 2 thema
# 1 thematik
# 1 theoretisch
# 2 there
# 7 they
# 1 think
# 3 this
# 1 time
# 1 tip
# 3 tipps
# 1 tips
# 1 tiptop
# 1 tja
# 1 tlw
# 4 to
# 1 toaster
# 3 toi
# 2 toll
# 2 tolle
# 3 toller
# 3 tolles
# 3 took
# 23 top
# 1 topspeed
# 2 tot
# 7 total
# 1 totalausfall
# 1 totale
# 1 totaler
# 2 totales
# 1 totzeiten
# 1 touchpad
# 1 touchpanel
# 1 traf
# 1 trage
# 1 tragen
# 1 tragenden
# 1 transparent
# 2 transparente
# 1 transporter
# 1 trat
# 1 traten
# 3 traurig
# 1 treffen
# 2 treibt
# 1 treten
# 1 treugeschenk
# 1 trifft
# 1 trockenen
# 1 trosdem
# 1 trots
# 52 trotz
# 14 trotzdem
# 1 trotzt
# 1 tschibo
# 2 tuechtig
# 1 tuekei
# 1 tuen
# 11 tun
# 6 tut
# 21 tv
# 1 uber
# 1 ud
# 1 udn
# 132 ueber
# 1 ueberall
# 4 ueberaus
# 1 ueberblick
# 1 ueberbruecken
# 1 ueberbrueckt
# 5 ueberbrueckung
# 1 ueberdie
# 2 ueberdurchschnittlich
# 1 ueberein
# 1 uebereinstimmen
# 1 ueberfaellig
# 1 ueberfordert
# 1 ueberforderte
# 1 ueberfordertem
# 1 ueberfuellte
# 4 uebergang
# 1 uebergangsloesung
# 1 uebergangsloesungen
# 1 uebergangstarif
# 1 uebergeben
# 32 ueberhaupt
# 1 ueberirdisches
# 1 ueberlege
# 1 ueberlegen
# 1 ueberm
# 2 uebermittelt
# 1 uebermittlung
# 8 uebernahme
# 1 uebernahmeversprechen
# 2 uebernehmen
# 6 uebernommen
# 1 ueberprueft
# 1 ueberpruefte
# 1 ueberpruefung
# 1 ueberragendes
# 5 ueberrascht
# 1 uebers
# 2 ueberschritten
# 2 uebersicht
# 6 uebersichtlich
# 1 uebersichtliche
# 1 uebersichtlicher
# 1 ueberteuert
# 2 uebertragungsgeschwindigkeit
# 1 uebertragungsqualitaet
# 2 uebertragungsrate
# 1 uebertsichtlich
# 1 ueberweisen
# 1 ueberwiegend
# 1 ueberwiesen
# 1 ueberzeugen
# 1 ueblich
# 1 uebliche
# 4 uebrig
# 1 uergend
# 24 uhr
# 1 uhrwerk
# 3 uhrzeit
# 1 uhrzeitangabe
# 1 uk
# 1 umaenderungen
# 1 umbauen
# 2 umfangreich
# 2 umfangreiche
# 1 umfangreiches
# 1 umfassende
# 1 umfassender
# 3 umgang
# 1 umgangen
# 1 umgangston
# 1 umgebucht
# 1 umgebung
# 2 umgehen
# 6 umgehend
# 1 umgekehrt
# 1 umgeschaltet
# 5 umgesetzt
# 5 umgestellt
# 1 umklemmen
# 1 umklemmung
# 1 umschalt
# 1 umschalten
# 1 umschalttermin
# 9 umschaltung
# 1 umsetzngsdauer
# 11 umsetzung
# 1 umsetzungsplan
# 4 umsonst
# 2 umstaende
# 2 umstaenden
# 2 umstaendlich
# 1 umstaendliche
# 1 umstellen
# 51 umstellung
# 2 umstellungstermin
# 1 umstellungstermines
# 2 umstieg
# 5 umts
# 1 umwege
# 1 umwerfend
# 1 umziehen
# 4 umzug
# 1 umzugehen
# 1 umzuges
# 1 umzugsbearbeitung
# 1 umzugsbedingt
# 1 umzugsservice
# 3 un
# 1 unabdingbar
# 1 unangebracht
# 1 unangefochten
# 1 unangemessen
# 2 unangemessene
# 3 unannehmlichkeiten
# 1 unavailable
# 1 unbeantwortet
# 1 unbedingt
# 2 unbefriedigend
# 1 unbekannt
# 1 unbenutzbar
# 1 unbeschreiblich
# 1 unbestimmte
# 5 unbuerokratisch
# 1 unbuerokratischer
# 2 undurchsichtig
# 1 undurchsichtige
# 1 uneingeschraenkt
# 1 unendliche
# 1 unerklaerlich
# 2 unertraeglich
# 1 unerwartet
# 1 unerwartete
# 5 unfaehig
# 1 unfaehiges
# 1 unfaehigkeit
# 1 unfassbar
# 6 unflexibel
# 1 unfreudlische
# 15 unfreundlich
# 3 unfreundliche
# 2 unfreundlichen
# 5 unfreundlicher
# 1 unfreundliches
# 2 unfreundlichste
# 2 ungenuegend
# 4 unglaublich
# 1 unhoeflichen
# 1 uninformierte
# 5 unitymedia
# 1 unk
# 1 unkentlich
# 2 unklare
# 2 unklarheit
# 4 unklarheiten
# 1 unklompiziert
# 1 unkompetent
# 1 unkompetente
# 1 unkompleziert
# 2 unkomplieziert
# 66 unkompliziert
# 25 unkomplizierte
# 1 unkompliziertem
# 9 unkomplizierter
# 2 unkompliziertes
# 1 unkomplizioert
# 1 unkooperativ
# 1 unkopliziert
# 1 unkoplizierter
# 1 unkosten
# 4 unmoeglich
# 1 unmoegliches
# 1 unmotiviert
# 1 unnoetig
# 2 unnoetige
# 1 unnuetz
# 1 unnuetzes
# 1 unpraezise
# 3 unproblematisch
# 2 unproblematische
# 1 unprofessionel
# 1 unproplematische
# 1 unschoen
# 7 unsere
# 5 unserem
# 5 unseren
# 7 unserer
# 1 unsicherheiten
# 3 unstimmigkeiten
# 1 unstrukturiertes
# 1 unten
# 1 unterbrechungen
# 1 unterbreitet
# 4 unterbrochen
# 1 untereinander
# 1 untergegangen
# 1 untergehen
# 3 unterirdisch
# 1 unterirdischer
# 18 unterlagen
# 1 unterlagenanforderung
# 1 unterlaufen
# 1 unterm
# 7 unternehmen
# 1 unternommen
# 3 unterrichtet
# 1 unterscheidlichen
# 2 unterschiedliche
# 1 unterschiedlichen
# 1 unterschiedlicher
# 1 unterschreibe
# 1 unterschreiben
# 1 unterschreibung
# 3 unterschrift
# 7 unterstuetzung
# 1 unterstuetzungshotlinie
# 4 unterwegs
# 1 untragbar
# 2 unuebersichtlich
# 1 unvereinbarste
# 1 unvergleichbar
# 1 unverhaeltnismaessig
# 4 unverschaemt
# 1 unverschaemte
# 1 unverschaemtheit
# 1 unversierte
# 1 unverstaendliche
# 1 unvollstaendig
# 2 unzaehlige
# 5 unzaehligen
# 5 unzufrieden
# 2 unzureichend
# 2 unzuverlaessig
# 1 unzuverlaessigkeit
# 1 unzuverlaessigkeiten
# 1 up
# 1 update
# 1 upgraden
# 4 upload
# 1 uploadgeschwindigkeit
# 12 urlaub
# 1 urlaubsantrag
# 1 urlaubstag
# 3 urlaubstage
# 1 urteil
# 2 usb
# 1 use
# 10 usw
# 1 vage
# 13 vdsl
# 2 verabreden
# 1 verabredet
# 1 verabredete
# 1 verabsaeumte
# 1 veraendert
# 1 veraergert
# 1 veralbern
# 1 veraltete
# 1 verantwortlich
# 1 verantwortlichen
# 1 verarbeitung
# 1 verarscht
# 1 verb
# 1 verbessern
# 2 verbessert
# 1 verbesserungswuerdig
# 2 verbindliche
# 1 verbindlichen
# 1 verbindlichkeit
# 48 verbindung
# 2 verbindungen
# 1 verbindungs
# 2 verbindungsabbrueche
# 1 verbindungsausfaellen
# 1 verbindungsgeschwindigkeiten
# 3 verbindungsprobleme
# 1 verbindungsschwierigkeiten
# 1 verbingung
# 1 verbliebenen
# 6 verbracht
# 1 verbraten
# 1 verbrauchers
# 1 verbucht
# 4 verbunden
# 1 verbundenen
# 2 verdacht
# 1 verdanke
# 1 verderben
# 1 verdrahtungs
# 1 verdrehte
# 2 vereinbaren
# 16 vereinbart
# 6 vereinbarte
# 1 vereinbarteb
# 19 vereinbarten
# 1 vereinbarter
# 1 vereinbarung
# 2 vereinbarungen
# 1 verfall
# 14 verfuegbar
# 1 verfuegbare
# 1 verfuegbaren
# 6 verfuegbarkeit
# 1 verfuegbarkeitscheck
# 1 verfuegbarkeitspruefung
# 1 verfuegen
# 16 verfuegung
# 1 verfuehbar
# 5 vergangen
# 1 vergangenen
# 1 vergebe
# 2 vergeblich
# 1 vergebliches
# 8 vergessen
# 1 vergessenen
# 1 vergeudete
# 1 vergiblich
# 3 vergingen
# 8 vergleich
# 1 vergleiche
# 1 vergleichportals
# 1 vergleichsweise
# 1 verguenstigung
# 1 verguetet
# 1 verguetung
# 1 verhaelt
# 4 verhaeltnis
# 1 verhaetnis
# 1 verhalten
# 1 verhandlungspartner
# 1 verkabelt
# 3 verkabelung
# 1 verkaeufer
# 1 verkauf
# 1 verkaufen
# 2 verkauft
# 1 verkauften
# 1 verklemmte
# 1 verkrampft
# 1 verl
# 1 verlaengert
# 1 verlaessliche
# 1 verlaessliches
# 1 verlaesslichkeit
# 1 verlangen
# 3 verlassen
# 1 verlauf
# 9 verlaufen
# 2 verlegen
# 1 verlegt
# 11 verlief
# 1 verliefen
# 1 verliehen
# 2 verlieren
# 1 verliererseite
# 4 verloren
# 2 verlorene
# 1 verlorenem
# 2 vermerkt
# 1 vermittelt
# 1 vermittler
# 1 vermittlung
# 1 vermittlungsgutschrift
# 1 vermutlich
# 1 verneinte
# 1 vernetzt
# 1 vernichtend
# 1 vernueftige
# 1 veroeffentlichen
# 1 verpackt
# 2 verpasst
# 1 verpasste
# 1 verpatzen
# 1 verpennt
# 1 verrechnung
# 1 verreissen
# 1 versaeumnis
# 1 versaeumt
# 8 versand
# 3 versandkosten
# 1 versandt
# 4 verschickt
# 2 verschieben
# 2 verschiebung
# 1 verschiebungen
# 2 verschiedene
# 5 verschiedenen
# 1 verschiedener
# 1 verschlafenen
# 1 verschlampt
# 1 verschmerzen
# 13 verschoben
# 1 verschpricht
# 3 verschulden
# 1 verschuldet
# 1 verschwenden
# 1 verschwendete
# 1 verschwunden
# 1 versehentlich
# 2 versendet
# 1 versetzt
# 1 versiert
# 1 versorgt
# 2 versorgung
# 3 verspaetet
# 1 verspaetete
# 2 verspaeteter
# 3 verspaetung
# 1 versprach
# 5 versprechen
# 1 versprechung
# 5 versprechungen
# 1 verspricht
# 1 versproche
# 14 versprochen
# 8 versprochene
# 7 versprochenen
# 1 versprochenes
# 1 versprohen
# 6 verstaendlich
# 11 verstaendliche
# 1 verstaendlichkeit
# 1 verstaendlickeit
# 1 verstaendnis
# 1 verstaendnisprobleme
# 1 verstand
# 3 verstanden
# 2 versteckte
# 1 versteckten
# 4 verstehen
# 1 verstehende
# 1 verstreicht
# 3 versuch
# 3 versuche
# 7 versuchen
# 11 versucht
# 2 vertag
# 2 verteiler
# 1 verteilerkasten
# 8 vertraege
# 1 vertraegen
# 142 vertrag
# 1 vertragdetails
# 13 vertrages
# 6 vertraglich
# 2 vertraglicher
# 2 vertrags
# 15 vertragsabschluss
# 1 vertragsabschlusses
# 4 vertragsabwicklung
# 1 vertragsanbahnung
# 2 vertragsangebot
# 1 vertragsbandbreite
# 1 vertragsbegin
# 10 vertragsbeginn
# 1 vertragsbindung
# 1 vertragsdabwicklung
# 2 vertragsdaten
# 1 vertragsdokumenten
# 2 vertragsende
# 1 vertragsfreigabe
# 1 vertragskonstellationsmodells
# 4 vertragslaufzeit
# 1 vertragsmonat
# 1 vertragsschluss
# 1 vertragsstatus
# 12 vertragsunterlagen
# 3 vertragswechsel
# 1 vertragwechsels
# 2 vertrauen
# 1 vertreiben
# 1 vertreten
# 1 vertrgaerfuellung
# 1 vertroeste
# 4 vertroestet
# 1 vertroestungen
# 1 verursachen
# 1 verursacht
# 1 verwandte
# 1 verwende
# 1 verwenden
# 1 verwendet
# 1 verwendung
# 2 verwiesen
# 1 verwirrend
# 1 verwirrung
# 1 verzicht
# 1 verzichten
# 1 verzoederungen
# 1 verzoegern
# 7 verzoegert
# 4 verzoegerte
# 9 verzoegerung
# 2 verzoegerungen
# 1 verzoergerung
# 1 verzug
# 1 verzugslose
# 1 verzweiflung
# 1 vestaendlich
# 6 vetrag
# 1 vetragsabschluss
# 1 vetragsunerlagen
# 6 via
# 1 videos
# 22 viele
# 13 vielen
# 1 vieler
# 3 vieles
# 1 vielfaches
# 2 vielleicht
# 7 vier
# 1 vierte
# 1 viertem
# 1 virtuellen
# 1 voadfone
# 1 vodafdone
# 17 vodafon
# 224 vodafone
# 3 vodafones
# 1 vodafoneshop
# 1 vodafonetv
# 1 vodahohn
# 1 vodaphon
# 2 vodaphone
# 1 vodfon
# 12 voellig
# 2 voip
# 8 voll
# 1 vollauf
# 7 volle
# 3 vollen
# 1 voller
# 3 vollkommen
# 1 vollmacht
# 1 vollmachten
# 1 vollmundige
# 1 vollstaendig
# 6 vollsten
# 3 vollzogen
# 1 volumen
# 1 volumenbegrenzung
# 1 vondafone
# 9 vorab
# 3 vorabinformationen
# 1 vorallem
# 11 voranbieter
# 1 voranbieters
# 1 vorangekuendigt
# 1 vorantreiben
# 1 voraus
# 2 voraussetzung
# 6 vorbei
# 1 vorbeikommen
# 1 vorbeizuschicken
# 1 vorbelastet
# 1 vorbemerkt
# 1 vorbereitungen
# 4 vorbildlich
# 1 vorerst
# 9 vorfeld
# 2 vorgaenger
# 4 vorgang
# 1 vorganges
# 1 vorgangs
# 1 vorgangsweise
# 1 vorgefertigte
# 1 vorgegeben
# 2 vorgegebenen
# 1 vorgehen
# 1 vorgenommen
# 1 vorgenommenen
# 2 vorgeschlagen
# 1 vorgestellt
# 1 vorgestern
# 1 vorgestzten
# 9 vorhanden
# 1 vorhandenen
# 1 vorhandener
# 1 vorhandenes
# 20 vorher
# 1 vorhergehenden
# 1 vorhergehender
# 2 vorherige
# 4 vorherigen
# 2 vorheriger
# 1 vorhierige
# 1 vorige
# 2 vorinstallation
# 1 vorkasse
# 1 vorkommen
# 1 vorlauf
# 2 vorlaufzeit
# 1 vorliegen
# 1 vorliegt
# 2 vormieter
# 3 vormittag
# 1 vormittags
# 2 vorn
# 1 vornamen
# 1 vornstatten
# 2 vorort
# 1 vorrausetztung
# 1 vorraussichtlich
# 1 vorrauszahlung
# 1 vorschlagen
# 1 vorsicht
# 2 vorstand
# 1 vorstands
# 1 vorstellen
# 1 vorstellungen
# 1 vorteil
# 1 voruebergehend
# 1 voruebergehende
# 1 vorverlegen
# 1 vorwahlnummern
# 1 vorweg
# 2 vorzeitig
# 1 vorziehen
# 2 vorzunehmen
# 1 vs
# 1 wa
# 2 waehlen
# 6 waehrend
# 2 waer
# 17 waere
# 4 waeren
# 3 wahl
# 1 wahnsinns
# 1 wahren
# 1 wahrgenommene
# 1 wahrheitswidrig
# 4 wahrscheinlich
# 1 waldeck
# 1 wan
# 18 wann
# 1 warb
# 1 ware
# 1 warf
# 2 wars
# 20 warte
# 1 warteliste
# 43 warten
# 1 wartens
# 1 wartenschlagen
# 1 wartenzeiten
# 1 warterei
# 4 warteschlange
# 3 warteschlangen
# 26 warteschleife
# 7 warteschleifen
# 1 wartescleifen
# 2 wartet
# 1 wartete
# 59 wartezeit
# 38 wartezeiten
# 12 warum
# 1 wasn
# 2 website
# 67 wechsel
# 1 wechselauftrags
# 3 wechselbonus
# 1 wechselkunden
# 9 wechseln
# 1 wechselpraemie
# 1 wechselprozess
# 2 wechsels
# 1 wechselte
# 1 wechselten
# 3 wechseltermin
# 3 wechsle
# 2 wechsler
# 1 weden
# 11 weder
# 1 week
# 1 weeks
# 24 wegen
# 1 weggeschickt
# 2 wegkomme
# 4 weihnachten
# 1 weis
# 5 weise
# 16 weiss
# 1 weisses
# 5 weit
# 1 weitem
# 6 weitere
# 7 weiterempfehlen
# 9 weiteren
# 1 weiterer
# 3 weiteres
# 1 weitergab
# 1 weitergabe
# 2 weitergegeben
# 3 weitergeholfen
# 1 weitergeht
# 10 weitergeleitet
# 1 weitergelietet
# 1 weiterhelfen
# 4 weiterhin
# 2 weiterleitung
# 1 weiterversorgen
# 1 welch
# 1 welcome
# 3 welt
# 1 wen
# 22 wenig
# 2 wenige
# 3 wenigen
# 14 weniger
# 1 wenigeren
# 1 wenigsten
# 2 wenigstens
# 4 wer
# 1 werbung
# 1 werk
# 1 werkseinstellungen
# 3 werktag
# 2 wert
# 1 werte
# 1 werten
# 4 wesentlich
# 1 weshalb
# 1 wettbewerb
# 1 wetter
# 1 wg
# 1 what
# 2 when
# 1 who
# 2 wichtig
# 2 wichtige
# 2 wichtigen
# 1 wichtiges
# 1 wichtigste
# 1 wider
# 5 widerruf
# 3 widerrufen
# 1 widerrufsfrist
# 1 widersprochen
# 1 widerspruechlich
# 1 widerspruechliche
# 1 widerspruechlichen
# 1 wiedergutmachung
# 2 wiederholt
# 3 wiederholte
# 1 wiederholter
# 1 wiederrufs
# 1 wiederspruechliche
# 1 wiederufsrecht
# 1 wiederum
# 1 wiesen
# 1 wieso
# 1 willkommen
# 2 willkommensbrief
# 1 wimpernschlag
# 1 windows
# 1 wirbt
# 25 wirklich
# 1 wirklichbdarauf
# 1 wirksam
# 1 wirkt
# 1 wisse
# 7 wissen
# 1 wissens
# 1 wissentlich
# 4 with
# 1 witz
# 11 wlan
# 1 wobei
# 36 woche
# 114 wochen
# 3 wochenende
# 5 wochenlang
# 1 wochenlange
# 3 wochenlangem
# 1 wochentags
# 1 wochrn
# 2 wodurch
# 1 woechentliches
# 1 woechige
# 3 wofuer
# 2 woher
# 11 wohl
# 1 wohlfuehlen
# 1 wohlgemerkt
# 1 wohlwollend
# 3 wohne
# 1 wohngebiet
# 2 wohnort
# 1 wohnsitz
# 10 wohnung
# 1 wohnzimmer
# 1 wolle
# 1 wollten
# 1 wont
# 25 worden
# 1 world
# 1 worquf
# 1 worst
# 3 wort
# 1 worte
# 2 worten
# 1 would
# 1 wqcqwc
# 1 wude
# 3 wuensche
# 4 wuenschen
# 2 wuenschenswert
# 1 wuenschte
# 28 wuerde
# 3 wuerden
# 1 wuesste
# 5 wunderbar
# 1 wundern
# 1 wunsch
# 1 wunschadresse
# 9 wunschtermin
# 352 wurde
# 81 wurden
# 1 wurdre
# 1 wurm
# 1 wusste
# 1 wussten
# 1 wut
# 1 wwig
# 1 wzeiten
# 1 xdsl
# 1 xmaliger
# 1 xp
# 1 zahl
# 1 zahlbaren
# 4 zahle
# 8 zahlen
# 1 zahlreichen
# 1 zahlreicher
# 1 zahlt
# 1 zahlung
# 1 zak
# 1 zehn
# 2 zeigen
# 45 zeit
# 1 zeitaufwendige
# 1 zeitaufwendigen
# 5 zeiten
# 1 zeitfenster
# 2 zeitgerecht
# 1 zeitgleich
# 1 zeitgruenden
# 1 zeitintensiv
# 1 zeitl
# 1 zeitliche
# 2 zeitlicher
# 7 zeitnah
# 5 zeitnahe
# 1 zeitnahen
# 1 zeitnaher
# 9 zeitpunkt
# 2 zeitrahmen
# 1 zeitraubend
# 7 zeitraum
# 1 zeitraumes
# 1 zeitschiene
# 2 zeitspanne
# 1 zeitverzoegerungen
# 1 zeitweilige
# 2 zeitweise
# 1 zentrale
# 1 zentrum
# 1 zettel
# 1 ziegler
# 1 ziehe
# 2 ziehen
# 2 zieht
# 1 ziel
# 1 zielfuehrend
# 1 zielfuehrende
# 1 zieltermi
# 9 ziemlich
# 3 zig
# 1 zmstellungstermin
# 1 zoegerliche
# 1 zoegerte
# 2 zubehoer
# 3 zubekommen
# 1 zuck
# 6 zudem
# 18 zuegig
# 10 zuegige
# 1 zuegiger
# 1 zuegigkeit
# 9 zuerst
# 1 zufaellig
# 1 zuferlaessig
# 51 zufrieden
# 12 zufriedenheit
# 1 zufriedenheitstelefonat
# 7 zufriedenstellend
# 10 zugang
# 1 zugangs
# 16 zugangsdaten
# 1 zugangsleistung
# 1 zugekommen
# 1 zugeleitet
# 1 zugeordnet
# 4 zugesagt
# 6 zugesagte
# 2 zugesagten
# 1 zugesagter
# 4 zugesandt
# 2 zugeschaltet
# 7 zugeschickt
# 1 zugesedet
# 4 zugesichert
# 1 zugesicherte
# 1 zugesicherten
# 1 zugestellt
# 1 zugetraut
# 1 zugewiesen
# 1 zugriff
# 1 zugsicherten
# 1 zuhaus
# 6 zuhause
# 2 zukommen
# 2 zukuenftig
# 1 zukunft
# 1 zulange
# 1 zulassungsdaten
# 1 zulegen
# 4 zuletzt
# 2 zumal
# 1 zumeisst
# 9 zumindest
# 1 zumutung
# 2 zunaechst
# 1 zunehmen
# 1 zunehmendem
# 1 zurechtfinden
# 1 zurechtzuruecken
# 16 zurueck
# 1 zurueckgegeben
# 1 zurueckgemeldet
# 3 zurueckgerufen
# 1 zurueckgeschickt
# 1 zurueckgeworben
# 1 zuruecksetzen
# 7 zusaetzlich
# 5 zusaetzliche
# 2 zusaetzlichen
# 2 zusaetzlicher
# 7 zusage
# 4 zusagen
# 3 zusammen
# 1 zusammenarbeit
# 1 zusammenbrueche
# 1 zusammengefasst
# 1 zusammenhang
# 1 zusammensetzung
# 1 zusammenvefasst
# 1 zusatnde
# 1 zusatzangeboten
# 1 zusatzinfos
# 2 zusatzkosten
# 1 zusatzleistungen
# 2 zuschaltung
# 1 zuschicken
# 1 zuschlag
# 1 zuschlaten
# 1 zusenden
# 6 zusendung
# 1 zusendungen
# 1 zusicherung
# 1 zusparen
# 2 zustaendig
# 2 zustaendige
# 2 zustaendigen
# 1 zustand
# 46 zustande
# 2 zustandekommen
# 1 zustandekommt
# 2 zustellung
# 1 zustimmung
# 1 zustimmungen
# 1 zutiefst
# 32 zuverlaessig
# 8 zuverlaessige
# 3 zuverlaessiger
# 10 zuverlaessigkeit
# 1 zuverlaessigste
# 1 zuverlaesslichkeit
# 4 zuvor
# 1 zuvorkommen
# 8 zuvorkommend
# 3 zuvorkommender
# 1 zuvorkomment
# 1 zuzugreifen
# 1 zwang
# 1 zwangspause
# 1 zwangsversteigerung
# 1 zwecke
# 2 zwecks
# 37 zwei
# 1 zweiein
# 6 zweimal
# 1 zweimaliges
# 2 zweite
# 4 zweiten
# 3 zweiter
# 1 zweites
# 1 zwischenanbieter
# 2 zwischendurch
# 1 zwischenstaende
# 2 zwischenzeitlich

# %% [markdown]
# ### Serialize data features

# %%
np.save(serialize_word2vec_features,train_data_features)

with codecs.open(serialize_word2vec_vocabulary,  'w', encoding='utf-8') as f:
	json.dump(vocab, f,  indent=3)

joblib.dump(vectorizer, serialize_word2vec_vectorizer)
# Out:
# ['/mnt/basket/processingData/volatile/telco_data_vectorizer.joblib']
